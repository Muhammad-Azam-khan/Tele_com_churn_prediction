# %% [markdown]
# # Problem Statement:
# - Help No-Churn with their use cases with ML
# 1. Understanding the variables that are influencing the customers
#    to migrate.
# 2. Creating Churn risk scores that can be indicative to drive
#    retention campaigns.
# 3. Introduce new predicting variable “CHURN-FLAG” with values
#    YES(1) or NO(0) so that email campaigns with lucrative offers
#    can be targeted to Churn YES customers help to identify possible CHURN-FLAG YES customers and provide more attention in customer touch point areas, including customer care support, request fulfilment, auto categorizing tickets as high priority for quick resolutions any questions they may have etc.

# %%
# !pip3 install lightgbm

# %%
# !pip install catboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import AdaBoostClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import VotingClassifier





from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score, confusion_matrix, classification_report,ConfusionMatrixDisplay

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Domain Analysis:
#
#
#
# 1. **State:** Represents the geographical location (state) where the customer resides, providing insights into regional demographics and market dynamics.
#
# 2. **Account Length:** Indicates the duration of time a customer has been subscribed to the telecom service, reflecting loyalty and potential for long-term customer relationships.
#
# 3. **Area Code:** Denotes the area code associated with the customer's phone number, offering information about regional telecommunications infrastructure and service coverage.
#
# 4. **Phone:** Unique identifier for each customer's phone number, facilitating individualized customer communication and tracking.
#
# 5. **International Plan:** Indicates whether the customer has subscribed to an international calling plan, influencing revenue streams and customer segmentation based on global communication needs.
#
# 6. **VMail Plan:** Flags whether the customer has a voicemail plan, impacting service offerings and customer communication preferences.
#
# 7. **VMail Message:** Quantifies the number of voicemail messages a customer has, reflecting engagement with voicemail services and potential for personalized outreach.
#
# 8. **Day Mins:** Total minutes of daytime usage by the customer, crucial for understanding usage patterns and optimizing tariff plans for daytime calling.
#
# 9. **Day Calls:** Total number of calls made by the customer during the day, indicating call frequency and potential for upselling additional services.
#
# 10. **Day Charge:** Total charges incurred for daytime usage, influencing pricing strategies and revenue generation from daytime calling.
#
# 11. **Eve Mins:** Total minutes of evening usage by the customer, informing service planning and resource allocation for evening hours.
#
# 12. **Eve Calls:** Total number of calls made by the customer during the evening, reflecting customer engagement and preferences during evening hours.
#
# 13. **Eve Charge:** Total charges incurred for evening usage, contributing to revenue streams and pricing models for evening calling.
#
# 14. **Night Mins:** Total minutes of nighttime usage by the customer, guiding network optimization and service quality enhancements for nighttime operations.
#
# 15. **Night Calls:** Total number of calls made by the customer during the night, indicating usage patterns and potential for service improvements during off-peak hours.
#
# 16. **Night Charge:** Total charges incurred for nighttime usage, contributing to revenue calculations and pricing strategies for nighttime services.
#
# 17. **International Mins:** Total minutes of international calling by the customer, influencing international service offerings and pricing structures for global communication.
#
# 18. **International calls:** Total number of international calls made by the customer, reflecting international communication needs and potential for targeted international service promotions.
#
# 19. **International Charge:** Total charges incurred for international calling, contributing to revenue from international services and tariff optimization for global connectivity.
#
# 20. **CustServ Calls:** Total number of customer service calls made by the customer, indicating service satisfaction levels and opportunities for service improvement and customer retention efforts.
#
# 21. **Churn:** Binary indicator of whether the customer has churned (switched to a competitor), crucial for churn prediction modeling and proactive customer retention strategies.

# %%
df = pd.read_csv('churn.csv')

# %%
pd.set_option('display.max_column',None)
df.head()
# Out:
#   State  Account Length  Area Code      Phone International_Plan Vmail_Plan  \
# 0    KS             128        415   382-4657                 no        yes
# 1    OH             107        415   371-7191                 no        yes
# 2    NJ             137        415   358-1921                 no         no
# 3    OH              84        408   375-9999                yes         no
# 4    OK              75        415   330-6626                yes         no
#
#    Vmail_Message  Day_Mins  Day_Calls  Day_Charge  Eve_Mins  Eve_Calls  \
# 0             25     265.1        110       45.07     197.4         99
# 1             26     161.6        123       27.47     195.5        103
# 2              0     243.4        114       41.38     121.2        110
# 3              0     299.4         71       50.90      61.9         88
# 4              0     166.7        113       28.34     148.3        122
#
#    Eve_Charge  Night_Mins  Night_Calls  Night_Charge  International_Mins  \
# 0       16.78       244.7           91         11.01                10.0
# 1       16.62       254.4          103         11.45                13.7
# 2       10.30       162.6          104          7.32                12.2
# 3        5.26       196.9           89          8.86                 6.6
# 4       12.61       186.9          121          8.41                10.1
#
#    International_calls  International_Charge   CustServ_Calls   Churn
# 0                    3                   2.70               1   False
# 1                    3                   3.70               1   False
# 2                    5                   3.29               0   False
# 3                    7                   1.78               2   False
# 4                    3                   2.73               3   False

# %%
df.tail()
# Out:
#      State  Account Length  Area Code      Phone International_Plan  \
# 4612    NY              57        510   345-7512                 no
# 4613    NM             177        408   343-6820                 no
# 4614    VT              67        408   338-4794                 no
# 4615    MI              98        415   355-8388                 no
# 4616    IN             140        415   409-6884                 no
#
#      Vmail_Plan  Vmail_Message  Day_Mins  Day_Calls  Day_Charge  Eve_Mins  \
# 4612        yes             25     144.0         81       24.48     187.2
# 4613        yes             29     189.0         91       32.13     303.1
# 4614        yes             33     127.5        126       21.68     296.1
# 4615        yes             23     168.9         98       28.71     226.3
# 4616         no              0     204.7        100       34.80     126.8
#
#       Eve_Calls  Eve_Charge  Night_Mins  Night_Calls  Night_Charge  \
# 4612        112       15.91       158.6          122          7.14
# 4613         96       25.76       163.6          116          7.36
# 4614        129       25.17       200.9           91          9.04
# 4615        117       19.24       165.5           96          7.45
# 4616        107       10.78       202.8          115          9.13
#
#       International_Mins  International_calls  International_Charge   \
# 4612                 8.5                    6                   2.30
# 4613                15.7                    1                   4.24
# 4614                13.0                    3                   3.51
# 4615                14.3                    3                   3.86
# 4616                12.1                    4                   3.27
#
#       CustServ_Calls   Churn
# 4612               3   False
# 4613               3   False
# 4614               1   False
# 4615               0   False
# 4616               2   False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4617 entries, 0 to 4616
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   State                  4617 non-null   object
#  1   Account Length         4617 non-null   int64
#  2   Area Code              4617 non-null   int64
#  3   Phone                  4617 non-null   object
#  4   International_Plan     4617 non-null   object
#  5   Vmail_Plan             4617 non-null   object
#  6   Vmail_Message          4617 non-null   int64
#  7   Day_Mins               4617 non-null   float64
#  8   Day_Calls              4617 non-null   int64
#  9   Day_Charge             4617 non-null   float64
#  10  Eve_Mins               4617 non-null   float64
#  11  Eve_Calls              4617 non-null   int64
#  12  Eve_Charge             4617 non-null   float64
#  13  Night_Mins             4617 non-null   float64
#  14  Night_Calls            4617 non-null   int64
#  15  Night_Charge           4617 non-null   float64
#  16  International_Mins     4617 non-null   float64
#  17  International_calls    4617 non-null   int64
#  18  International_Charge   4617 non-null   float64
#  19  CustServ_Calls         4617 non-null   int64
#  20  Churn                  4617 non-null   object
# dtypes: float64(8), int64(8), object(5)
# memory usage: 757.6+ KB

# %%
df.shape
# Out:
# (4617, 21)

# %%
df.size
# Out:
# 96957

# %%
df.describe()
# Out:
#        Account Length    Area Code  Vmail_Message     Day_Mins    Day_Calls  \
# count     4617.000000  4617.000000    4617.000000  4617.000000  4617.000000
# mean       100.645224   437.046350       7.849903   180.447152   100.054364
# std         39.597194    42.288212      13.592333    53.983540    19.883027
# min          1.000000   408.000000       0.000000     0.000000     0.000000
# 25%         74.000000   408.000000       0.000000   143.700000    87.000000
# 50%        100.000000   415.000000       0.000000   180.000000   100.000000
# 75%        127.000000   510.000000      17.000000   216.800000   113.000000
# max        243.000000   510.000000      51.000000   351.500000   165.000000
#
#         Day_Charge     Eve_Mins    Eve_Calls   Eve_Charge   Night_Mins  \
# count  4617.000000  4617.000000  4617.000000  4617.000000  4617.000000
# mean     30.676576   200.429088   100.179770    17.036703   200.623933
# std       9.177145    50.557001    19.821314     4.297332    50.543616
# min       0.000000     0.000000     0.000000     0.000000    23.200000
# 25%      24.430000   165.900000    87.000000    14.100000   167.100000
# 50%      30.600000   200.800000   101.000000    17.070000   200.800000
# 75%      36.860000   234.000000   114.000000    19.890000   234.900000
# max      59.760000   363.700000   170.000000    30.910000   395.000000
#
#        Night_Calls  Night_Charge  International_Mins  International_calls  \
# count  4617.000000   4617.000000         4617.000000          4617.000000
# mean     99.944120      9.028185           10.279294             4.433831
# std      19.935053      2.274488            2.757361             2.457615
# min      12.000000      1.040000            0.000000             0.000000
# 25%      87.000000      7.520000            8.600000             3.000000
# 50%     100.000000      9.040000           10.300000             4.000000
# 75%     113.000000     10.570000           12.100000             6.000000
# max     175.000000     17.770000           20.000000            20.000000
#
#        International_Charge   CustServ_Calls
# count            4617.000000     4617.000000
# mean                2.775926        1.567035
# std                 0.744413        1.307019
# min                 0.000000        0.000000
# 25%                 2.320000        1.000000
# 50%                 2.780000        1.000000
# 75%                 3.270000        2.000000
# max                 5.400000        9.000000

# %% [markdown]
# Here are some insights from the provided `df.describe()` output:
#
# 1. **Account Length:**
#    - The average account length is approximately 100.6 length, with a standard deviation of 39.6 length.
#    - Account lengths range from 1 month to a maximum of 243 months.
#
# 2. **Area Code:**
#    - Area codes range from 408 to 510.
#    - Most customers seem to have area code 415, 408, or 510.
#
# 3. **Voicemail Messages:**
#    - On average, customers receive around 7.85 voicemail messages.
#    - There is a wide range in the number of voicemail messages, from 0 to a maximum of 51.
#
# 4. **Daytime Minutes (Day_Mins):**
#    - The average number of daytime minutes is approximately 180.4, with a standard deviation of 53.98.
#    - Daytime minutes range from 0 to a maximum of 351.5 minutes.
#
# 5. **Daytime Calls (Day_Calls):**
#    - The average number of daytime calls is approximately 100.1, with a standard deviation of 19.88.
#    - Daytime calls range from 0 to a maximum of 165 calls.
#
# 6. **Daytime Charge (Day_Charge):**
#    - The average daytime charge is approximately $30.68, with a standard deviation of $9.18.
#    - Daytime charges range from $0 to a maximum of $59.76.
#
# 7. **Evening Minutes (Eve_Mins), Evening Calls (Eve_Calls), and Evening Charge (Eve_Charge):**
#    - Similar statistics as daytime metrics but for evening usage.
#
# 8. **Nighttime Minutes (Night_Mins), Nighttime Calls (Night_Calls), and Nighttime Charge (Night_Charge):**
#    - Similar statistics as daytime metrics but for nighttime usage.
#
# 9. **International Minutes (International_Mins), International Calls (International_calls), and International Charge (International_Charge):**
#    - Similar statistics as daytime metrics but for international usage.
#
# 10. **Customer Service Calls (CustServ_Calls):**
#     - On average, customers make approximately 1.57 customer service calls, with a standard deviation of 1.31.
#     - Most customers seem to make 0 to 2 customer service calls, but there are outliers with up to 9 calls.

# %%
df.describe(include = 'O')
# Out:
#        State      Phone International_Plan Vmail_Plan   Churn
# count   4617       4617               4617       4617    4617
# unique    51       4617                  2          2       2
# top       WV   382-4657                 no         no   False
# freq     149          1               4171       3381    3961

# %%
df.sample(5)
# Out:
#      State  Account Length  Area Code      Phone International_Plan  \
# 2627    AK              86        408   389-4602                 no
# 3003    WV              95        415   356-7511                 no
# 4439    AR             115        415   353-5289                 no
# 1123    VA              11        408   358-6796                 no
# 3171    NH             100        408   407-3121                 no
#
#      Vmail_Plan  Vmail_Message  Day_Mins  Day_Calls  Day_Charge  Eve_Mins  \
# 2627         no              0     150.8         85       25.64     295.9
# 3003         no              0     134.4        104       22.85     152.4
# 4439        yes             37     184.1         67       31.30     159.4
# 1123        yes             24     131.5         98       22.36     230.2
# 3171         no              0     218.8        125       37.20     148.3
#
#       Eve_Calls  Eve_Charge  Night_Mins  Night_Calls  Night_Charge  \
# 2627         88       25.15       247.2          104         11.12
# 3003         95       12.95       236.5           80         10.64
# 4439        104       13.55       193.3          121          8.70
# 1123        111       19.57       283.7           87         12.77
# 3171        102       12.61       277.8           97         12.50
#
#       International_Mins  International_calls  International_Charge   \
# 2627                12.5                    1                   3.38
# 3003                 9.4                    3                   2.54
# 4439                13.3                    3                   3.59
# 1123                10.0                    3                   2.70
# 3171                 9.7                    6                   2.62
#
#       CustServ_Calls   Churn
# 2627               1   False
# 3003               1   False
# 4439               0   False
# 1123               2   False
# 3171               1   False

# %%
print("Features names :\n",df.columns.values)
# Out:
# Features names :
#  ['State' 'Account Length' 'Area Code' 'Phone' 'International_Plan'
#  'Vmail_Plan' 'Vmail_Message' 'Day_Mins' 'Day_Calls' 'Day_Charge'
#  'Eve_Mins' 'Eve_Calls' 'Eve_Charge' 'Night_Mins' 'Night_Calls'
#  'Night_Charge' 'International_Mins' 'International_calls'
#  'International_Charge ' 'CustServ_Calls' 'Churn']

# %%
# unique columns for unique values categorical variables:
unique_category = []
for column in df.columns:
    if df[column].dtypes == object and len(df[column].unique()) <= 50:
        unique_category.append(column)
        print(f"{column} : {df[column].unique()}")
        print(f"{column}: \n{df[column].value_counts()}")
        print("==="*10)
# Out:
# International_Plan : [' no' ' yes']
# International_Plan:
#  no     4171
#  yes     446
# Name: International_Plan, dtype: int64
# ==============================
# Vmail_Plan : [' yes' ' no']
# Vmail_Plan:
#  no     3381
#  yes    1236
# Name: Vmail_Plan, dtype: int64
# ==============================
# Churn : [' False' ' True']
# Churn:
#  False    3961
#  True      656
# Name: Churn, dtype: int64
# ==============================

# %%
# unique_values of numerical features:
unique_numerical = []

for column in df.columns:
    if df[column].dtypes == 'int64' or df[column].dtypes == 'float64':
        if len(df[column].unique()):
            unique_numerical.append(column)
            print(f"{column}:\n{df[column].unique()}")
            print("=="*10)
# Out:
# Account Length:
# [128 107 137  84  75 118 121 147 117 141  65  74 168  95  62 161  85  93
#   76  73  77 130 111 132 174  57  54  20  49 142 172  12  72  36  78 136
#  149  98 135  34 160  64  59 119  97  52  60  10  96  87  81  68 125 116
#   38  40  43 113 126 150 138 162  90  50  82 144  46  70  55 106  94 155
#   80 104  99 120 108 122 157 103  63 112  41 193  61  92 131 163  91 127
#  110 140  83 145  56 151 139   6 115 146 185 148  32  25 179  67  19 170
#  164  51 208  53 105  66  86  35  88 123  45 100 215  22  33 114  24 101
#  143  48  71 167  89 199 166 158 196 209  16  39 173 129  44  79  31 124
#   37 159 194 154  21 133 224  58  11 109 102 165  18  30 176  47 190 152
#   26  69 186 171  28 153 169  13  27   3  42 189 156 134 243  23   1 205
#  200   5   9 178 181 182 217 177 210  29 180   2  17   7 212 232 192 195
#  197 225 184 191 201  15 183 202   8 175   4 188 204 221 187  14 238 216
#  222 233]
# ====================
# Area Code:
# [415 408 510]
# ====================
# Vmail_Message:
# [25 26  0 24 37 27 33 39 30 41 28 34 46 29 35 21 32 42 36 22 23 43 31 38
#  40 48 18 17 45 16 20 14 19 51 15 11 12 47  8 44 49  4 10 13 50  9  6]
# ====================
# Day_Mins:
# [265.1 161.6 243.4 ... 200.5 278.1 127.5]
# ====================
# Day_Calls:
# [110 123 114  71 113  98  88  79  97  84 137 127  96  70  67 139  66  90
#  117  89 112 103  86  76 115  73 109  95 105 121 118  94  80 128  64 106
#  102  85  82  77 120 133 135 108  57  83 129  91  92  74  93 101 146  72
#   99 104 125  61 100  87 131  65 124 119  52  68 107  47 116 151 126 122
#  111 145  78 136 140 148  81  55  69 158 134 130  63  53  75 141 163  59
#  132 138  54  58  62 144 143 147  36  40 150  56  51 165  30  48  60  42
#    0  45 160 149 152 142 156  35  49 157  44  50  34  39  46]
# ====================
# Day_Charge:
# [45.07 27.47 41.38 ... 34.09 47.28 21.68]
# ====================
# Eve_Mins:
# [197.4 195.5 121.2 ... 213.5 303.1 296.1]
# ====================
# Eve_Calls:
# [ 99 103 110  88 122 101 108  94  80 111  83 148  71  75  76  97  90  65
#   93 121 102  72 112 100  84 109  63 107 115 119 116  92  85  98 118  74
#  117  58  96  66  67  62  77 164 126 142  64 104  79  95  86 105  81 113
#  106  59  48  82  87 123 114 140 128  60  78 125  91  46 138 129  89 133
#  136  57 135 139  51  70 151 137 134  73 152 168  68 120  69 127 132 143
#   61 124  42  54 131  52 149  56  37 130  49 146 147  55  12  50 157 155
#   45 144  36 156  53 141  44 153 154 150  43   0 145 159 170  47 169]
# ====================
# Eve_Charge:
# [16.78 16.62 10.3  ... 14.46 18.15 25.17]
# ====================
# Night_Mins:
# [244.7 254.4 162.6 ... 280.3 270.8 124.4]
# ====================
# Night_Calls:
# [ 91 103 104  89 121 118  96  90  97 111  94 128 115  99  75 108  74 133
#   64  78 105  68 102 148  98 116  71 109 107 135  92  86 127  79  87 129
#   57  77  95  54 106  53  67 139  60 100  61  73 113  76 119  88  84  62
#  137  72 142 114 126 122  81 123 117  82  80 120 130 134  59 112 132 110
#  101 150  69 131  83  93 124 136 125  66 143  58  55  85  56  70  46  42
#  152  44 145  50 153  49 175  63 138 154 140 141 146  65  51 151 158 155
#  157 147 144 149 166  52  33 156  38  36  48 164  40 168 161 159 160 170
#   41  12 165  43]
# ====================
# Night_Charge:
# [11.01 11.45  7.32 ... 14.57  4.78  5.6 ]
# ====================
# International_Mins:
# [10.  13.7 12.2  6.6 10.1  6.3  7.5  7.1  8.7 11.2 12.7  9.1 12.3 13.1
#   5.4 13.8  8.1 13.  10.6  5.7  9.5  7.7 10.3 15.5 14.7 11.1 14.2 12.6
#  11.8  8.3 14.5 10.5  9.4 14.6  9.2  3.5  8.5 13.2  7.4  8.8 11.   7.8
#   6.8 11.4  9.3  9.7 10.2  8.   5.8 12.1 12.  11.6  8.2  6.2  7.3  6.1
#  11.7 15.   9.8 12.4  8.6 10.9 13.9  8.9  7.9  5.3  4.4 12.5 11.3  9.
#   9.6 13.3 20.   7.2  6.4 14.1 14.3  6.9 11.5 15.8 12.8 16.2  0.  11.9
#   9.9  8.4 10.8 13.4 10.7 17.6  4.7  2.7 13.5 12.9 14.4 10.4  6.7 15.4
#   4.5  6.5 15.6  5.9 18.9  7.6  5.   7.  14.  18.  16.  14.8  3.7  2.
#   4.8 15.3  6.  13.6 17.2 17.5  5.6 18.2  3.6 16.5  4.6  5.1  4.1 16.3
#  14.9 16.4 16.7  1.3 15.2 15.1 15.9  5.5 16.1  4.  16.9  5.2  4.2 15.7
#  17.   3.9  3.8  2.2 17.1  4.9 17.9 17.3 18.4 17.8  4.3  2.9  3.1  3.3
#   2.6  3.4  1.1 18.3 16.6  2.1  2.4  2.5 18.7 16.8  0.4 19.3 19.2 19.7]
# ====================
# International_calls:
# [ 3  5  7  6  4  2  9 19  1 10 15  8 11  0 12 13 18 14 16 20 17]
# ====================
# International_Charge :
# [2.7  3.7  3.29 1.78 2.73 1.7  2.03 1.92 2.35 3.02 3.43 2.46 3.32 3.54
#  1.46 3.73 2.19 3.51 2.86 1.54 2.57 2.08 2.78 4.19 3.97 3.   3.83 3.4
#  3.19 2.24 3.92 2.84 2.54 3.94 2.48 0.95 2.3  3.56 2.   2.38 2.97 2.11
#  1.84 3.08 2.51 2.62 2.75 2.16 1.57 3.27 3.24 3.13 2.21 1.67 1.97 1.65
#  3.16 4.05 2.65 3.35 2.32 2.94 3.75 2.4  2.13 1.43 1.19 3.38 3.05 2.43
#  2.59 3.59 5.4  1.94 1.73 3.81 3.86 1.86 3.11 4.27 3.46 4.37 0.   3.21
#  2.67 2.27 2.92 3.62 2.89 4.75 1.27 0.73 3.65 3.48 3.89 2.81 1.81 4.16
#  1.22 1.76 4.21 1.59 5.1  2.05 1.35 1.89 3.78 4.86 4.32 4.   1.   0.54
#  1.3  4.13 1.62 3.67 4.64 4.73 1.51 4.91 0.97 4.46 1.24 1.38 1.11 4.4
#  4.02 4.43 4.51 0.35 4.1  4.08 4.29 1.49 4.35 1.08 4.56 1.4  1.13 4.24
#  4.59 1.05 1.03 0.59 4.62 1.32 4.83 4.67 4.97 4.81 1.16 0.78 0.84 0.89
#  0.7  0.92 0.3  4.94 4.48 0.57 0.65 0.68 5.05 4.54 0.11 5.21 5.18 5.32]
# ====================
# CustServ_Calls:
# [1 0 2 3 4 5 7 9 6 8]
# ====================

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().any()
# Out:
# State                    False
# Account Length           False
# Area Code                False
# Phone                    False
# International_Plan       False
# Vmail_Plan               False
# Vmail_Message            False
# Day_Mins                 False
# Day_Calls                False
# Day_Charge               False
# Eve_Mins                 False
# Eve_Calls                False
# Eve_Charge               False
# Night_Mins               False
# Night_Calls              False
# Night_Charge             False
# International_Mins       False
# International_calls      False
# International_Charge     False
# CustServ_Calls           False
# Churn                    False
# dtype: bool

# %%
df.dtypes
# Out:
# State                     object
# Account Length             int64
# Area Code                  int64
# Phone                     object
# International_Plan        object
# Vmail_Plan                object
# Vmail_Message              int64
# Day_Mins                 float64
# Day_Calls                  int64
# Day_Charge               float64
# Eve_Mins                 float64
# Eve_Calls                  int64
# Eve_Charge               float64
# Night_Mins               float64
# Night_Calls                int64
# Night_Charge             float64
# International_Mins       float64
# International_calls        int64
# International_Charge     float64
# CustServ_Calls             int64
# Churn                     object
# dtype: object

# %%
# Standardize phone number format (e.g., remove dashes)
# df['Phone'] = df['Phone'].str.replace('-', '')

# %%
df.head()
# Out:
#   State  Account Length  Area Code      Phone International_Plan Vmail_Plan  \
# 0    KS             128        415   382-4657                 no        yes
# 1    OH             107        415   371-7191                 no        yes
# 2    NJ             137        415   358-1921                 no         no
# 3    OH              84        408   375-9999                yes         no
# 4    OK              75        415   330-6626                yes         no
#
#    Vmail_Message  Day_Mins  Day_Calls  Day_Charge  Eve_Mins  Eve_Calls  \
# 0             25     265.1        110       45.07     197.4         99
# 1             26     161.6        123       27.47     195.5        103
# 2              0     243.4        114       41.38     121.2        110
# 3              0     299.4         71       50.90      61.9         88
# 4              0     166.7        113       28.34     148.3        122
#
#    Eve_Charge  Night_Mins  Night_Calls  Night_Charge  International_Mins  \
# 0       16.78       244.7           91         11.01                10.0
# 1       16.62       254.4          103         11.45                13.7
# 2       10.30       162.6          104          7.32                12.2
# 3        5.26       196.9           89          8.86                 6.6
# 4       12.61       186.9          121          8.41                10.1
#
#    International_calls  International_Charge   CustServ_Calls   Churn
# 0                    3                   2.70               1   False
# 1                    3                   3.70               1   False
# 2                    5                   3.29               0   False
# 3                    7                   1.78               2   False
# 4                    3                   2.73               3   False

# %%
print("Features names :\n",df.columns.values)
# Out:
# Features names :
#  ['State' 'Account Length' 'Area Code' 'Phone' 'International_Plan'
#  'Vmail_Plan' 'Vmail_Message' 'Day_Mins' 'Day_Calls' 'Day_Charge'
#  'Eve_Mins' 'Eve_Calls' 'Eve_Charge' 'Night_Mins' 'Night_Calls'
#  'Night_Charge' 'International_Mins' 'International_calls'
#  'International_Charge ' 'CustServ_Calls' 'Churn']

# %%
# Remove leading spaces from columns
df.columns = df.columns.str.strip()
df.head(2)
# Out:
#   State  Account Length  Area Code      Phone International_Plan Vmail_Plan  \
# 0    KS             128        415   382-4657                 no        yes
# 1    OH             107        415   371-7191                 no        yes
#
#    Vmail_Message  Day_Mins  Day_Calls  Day_Charge  Eve_Mins  Eve_Calls  \
# 0             25     265.1        110       45.07     197.4         99
# 1             26     161.6        123       27.47     195.5        103
#
#    Eve_Charge  Night_Mins  Night_Calls  Night_Charge  International_Mins  \
# 0       16.78       244.7           91         11.01                10.0
# 1       16.62       254.4          103         11.45                13.7
#
#    International_calls  International_Charge  CustServ_Calls   Churn
# 0                    3                   2.7               1   False
# 1                    3                   3.7               1   False

# %%
df.Churn.value_counts()
# Out:
#  False    3961
#  True      656
# Name: Churn, dtype: int64

# %%
# df['Churn'] = df['Churn'].str.replace('.',"")

# %%
df['Churn'].dtypes
# Out:
# dtype('O')

# %%
df['Churn'].unique()
# Out:
# array([' False', ' True'], dtype=object)

# %%
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()

# df1 = df.copy(deep = True)
# text_data_features = [i for i in list(df.columns) if i not in list(df.describe().columns)]

# print('Label Encoder Transformation')
# for i in text_data_features :
#     df1[i] = le.fit_transform(df1[i])
#     print(i,' : ',df1[i].unique(),' = ',le.inverse_transform(df1[i].unique()))

# %%
df.Churn.value_counts()
# Out:
#  False    3961
#  True      656
# Name: Churn, dtype: int64

# %%
df['Churn'].unique()
# Out:
# array([' False', ' True'], dtype=object)

# %%
df['Churn'] = df['Churn'].map({' False':0, ' True':1})

# %% [markdown]
# # EDA:

# %%
from ydata_profiling import ProfileReport
import sweetviz as sv

# %%
# result = sv.analyze(df)
# result.show_notebook()

# %% [markdown]
# ### Insights for Sweetviz
#
# 1. Area Code:
# - With 48% representation, area code indicates a significant concentration of customers in this geographic region.
# - With 26% representation, it signifies substantial customer bases in their respective regions.
# 2. International Plan:
# - The data indicates that 90% of customers do not have an international plan, as represented by the "no" category.
# - This suggests that the majority of customers may not have a need for international calling features or may prefer alternative communication methods for international calls.
# - Only 10% of customers have an international plan, as indicated by the "yes" category.
# - This suggests that international calling features may not be a significant factor influencing customer decisions.
# 3. Vmail Plan:
# - A significant majority, comprising 71% of customers, do not subscribe to the voicemail plan.Potentially indicating a preference for alternative communication methods or a lower perceived value of voicemail features.
# - Conversely, 29% of customers have opted for the voicemail plan, as denoted by the "yes" category.
# - While less prevalent than non-subscribers, this still represents a notable segment of the customer base who find value in voicemail services, such as message storage and retrieval capabilities.
# 4. CustServ Calls:
# - A significant portion, comprising 37%, of customers have made no customer service calls, as indicated by the "0" category.
# - This suggests that a large segment of customers may be satisfied with the service provided from customer support.
# - Approximately 21% of customers have made one customer service call, while 20% have made two calls.
# - This indicates a moderate level of engagement with customer support, with these customers likely encountering seeking assistance for specific concerns.
# 5. Churn:
# - The majority of customers, accounting for 87%, are labeled as "False," indicating that they have not churned.
# - This suggests that a significant portion of the customer base is satisfied with the service or finds value in the product, leading to continued subscription or usage.
# - Conversely, 13% of customers are labeled as "True," indicating that they have churned.
# - While this represents a minority of the customer base, it is still a significant proportion that warrants attention.

# %%
# mr = ProfileReport(df)
# mr.to_notebook_iframe()

# %%
continous_feature = df[['Account Length', 'Area Code', 'Vmail_Message', 'Day_Mins', 'Day_Calls',
       'Day_Charge', 'Eve_Mins', 'Eve_Calls', 'Eve_Charge', 'Night_Mins',
       'Night_Calls', 'Night_Charge', 'International_Mins','International_Charge']]

# %% [markdown]
# # Univariate analysis:

# %%
sns.set(style = 'darkgrid')

# %%
plt.figure(figsize = (15, 20), facecolor = 'white')
plotnumber = 1
for column in continous_feature.columns:
    if plotnumber <= 16:
        plt.subplot(4,4, plotnumber)
        sns.histplot( x = df[column], kde = True, palette='bright')
        plt.title(f"Histplot of {column}")
        plt.xlabel(column, fontsize = 15)
        plt.ylabel("Counts", fontsize = 15)
        plotnumber += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# # Bivariate Analysis:

# %%
plt.figure(figsize = (15, 20), facecolor = 'white')
plotnumber =1
for column in continous_feature.columns:
    if plotnumber <= 16:
        plt.subplot(4,4,plotnumber)
        sns.histplot(x = df[column], hue = df['Churn'], multiple='stack', palette='bright', bins=10, kde = True)
        plt.title(f"Histplot of {column.capitalize()} for bivariate analysis")
        plt.xlabel(column, fontsize = 10)
        plt.ylabel('Counts', fontsize= 10)
        plotnumber += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# # Univariate Analysis of Discrete feature :

# %%
discret_feat = df[['International_calls','CustServ_Calls','Churn']]

# %%
plt.figure(figsize = (10, 10), facecolor = 'white')
plotnumber = 1
for column in discret_feat.columns:
    if plotnumber <= 4:
        plt.subplot(2,2,plotnumber)
        sns.countplot(x = df[column])
        plt.title(f"Countplot of {column}")
        plt.xlabel(column, fontsize = 10)
        plt.ylabel("Counts", fontsize = 10)
        plotnumber += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insights for discrete features >:
#
# ## International_Calls:
#
# 1. **Moderate Calling Activity:** The majority of customers engage in a moderate level of international calling activity, with the most common counts being 3 and 4 calls.
#
# 2. **Decreasing Frequency:** The frequency of customers making international calls decreases gradually as the number of calls increases.
#
# 3. **Rare High Call Counts:** There are very few instances of customers making a high number of international calls (e.g., 15, 16, 18, 19, 20), indicating that extensive international calling is uncommon.
#
#
# ## Insights from CustServ_Calls:
#
# 1. **Common Scenarios:**
#    - Most customers made 1 or 2 service calls, indicating swift issue resolution for the majority.
#    - A notable portion didn't call, suggesting satisfaction or no need for assistance.
#
# 2. **Decreasing Frequency:**
#    - Frequency declines sharply beyond 2 calls, indicating rare instances of multiple interactions.
#    - Few customers made more than 4 calls, implying uncommon prolonged issues.
#
# 3. **Customer Experience:**
#    - Majority's issues resolved within 1-2 calls, positive for overall satisfaction.
#    - Few multiple calls suggest potential unresolved issues, addressing which could enhanc
# ## Insights for the target variable "Churn":
#
# 1. **Churn Rate:**
#    - Out of all customers, 656 churned, indicating a churn rate of approximately 14%.
#
# 2. **Retention Rate:**
#    - The majority (3961) did not churn, representing a retention rate of around 86%.e loyalty.

# %%
plt.figure(figsize = (10, 10), facecolor = 'white')
plotnumber = 1
for column in discret_feat.columns:
    if plotnumber <= 4:
        plt.subplot(2,2,plotnumber)
        sns.countplot(x = df[column], hue = df['Churn'])
        plt.title(f"Countplot of {column}")
        plt.xlabel(column, fontsize = 10)
        plt.ylabel("Counts", fontsize = 10)
        plotnumber += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# #  Bivariate Analysis of Discrete Feature
#
# ### ** "International_calls"  & "Churn":
#
# 1. **Inverse Relationship:** Generally, as international call counts rise, churn rates tend to decrease.
# 2. **Lower Churn Rates:** Customers making more international calls show lower likelihoods of leaving.
# 3. **Threshold Effect:** Around 3 to 5 international calls, churn rates stabilize or decrease further.
# 4. **Retention Indicator:** Higher international call activity may indicate satisfied customers less likely to churn.
#
#
#
#
# ### "CustServ_Calls" with respect to churn:
#
# 1. **Churn Trends with Service Calls:**
#    - Customers who made no service calls (0 calls) have a relatively high churn rate compared to those who made service calls.
#    - As the number of service calls increases, churn rates generally tend to decrease.
#
# 2. **Churn Rate Variation:**
#    - Customers with fewer service calls (0-3 calls) exhibit higher churn rates, while those with more service calls (4-5 calls) show lower churn rates.
#
# 3. **Optimal Service Call Range:**
#    - There seems to be an optimal range of service calls (around 4-5 calls) associated with lower churn rates.
#    - Beyond this range, churn rates increase slightly, suggesting potential dissatisfaction despite the increased support interactions.
#
# 4. **Service Call Impact on Retention:**
#    - Higher engagement with customer service through a moderate number of calls appears to correlate with better retention, indicating the importance of effective support interactions in customer retention efforts.

# %% [markdown]
# # Categorical Features :

# %%
categ_feat= df[['State', 'International_Plan', 'Vmail_Plan']]
categ_feat.head()
# Out:
#   State International_Plan Vmail_Plan
# 0    KS                 no        yes
# 1    OH                 no        yes
# 2    NJ                 no         no
# 3    OH                yes         no
# 4    OK                yes         no

# %%
plt.figure(figsize = (10,15), facecolor = 'white')
plotnumber = 1
for column in categ_feat.columns:
    if plotnumber <= 4:
        plt.subplot(2,2,plotnumber)
        sns.countplot(x = df[column])
        plt.title(f"Countplot of {column}")
        plt.xlabel(column, fontsize= 10)
        plt.ylabel('Occurance', fontsize = 10)
        plotnumber += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# # Univariate Analysis of Categorical_Feature:
#
#
# ### "International_Plan" feature:
#
# 1. **Distribution of International Plan Subscribers:**
#    - The majority of customers (4171) do not have an international plan, while a smaller portion (446) have opted for one.
#
# 2. **Insights:**
#    - Most customers do not subscribe to an international plan, indicating potential preferences or cost considerations.
#    - Understanding the characteristics and behaviors of customers with and without international plans can inform targeted marketing strategies and service offerings.
#
# ### Vmail_Plan:
#
#
# 1. **Distribution of Voicemail Plan Subscribers:**
#    - The majority of customers (3381) do not have a voicemail plan, while a substantial portion (1236) have opted for one.
#
# 2. **Insights:**
#    - Most customers do not subscribe to a voicemail plan, indicating potential preferences or usage patterns.
#    - Understanding the characteristics and behaviors of customers with and without voicemail plans can inform targeted marketing strategies and service offerings.

# %% [markdown]
# ### Bivariate Analysis of Categorical Features:

# %%
plt.figure(figsize = (10,15), facecolor = 'white')
plotnumber = 1
for column in categ_feat.columns:
    if plotnumber <= 4:
        plt.subplot(2,2,plotnumber)
        sns.countplot(x = df[column], hue = df['Churn'])
        plt.title(f"Countplot of {column}")
        plt.xlabel(column, fontsize= 10)
        plt.ylabel('Occurance', fontsize = 10)
        plotnumber += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights from Bivariate analays of categorical Features:
#
# ### International Plan:
#
# 1. **Churn by International Plan:**
#    - Customers without an international plan are the majority in both churned and non-churned categories.
#    - Churn rates are higher among customers with an international plan compared to those without it.
#
# 2. **Impact of International Plan:**
#    - Having an international plan doesn't guarantee customer retention, as evidenced by the significant churn among plan subscribers.
#
# 3. **Retention Focus:**
#    - While most non-plan customers stay, there's room to improve retention strategies for international plan subscribers.
#
#
# ### Vmail_plan:
#
# 1. **Churn and Voicemail Plan:**
#    - Most customers without a voicemail plan leave (churn), while many stay.
#    - Customers with a voicemail plan are less likely to leave compared to those without it.
#
# 2. **Effect of Voicemail Plan:**
#    - Having a voicemail plan helps keep customers around.
#
# 3. **Opportunities for Retention:**
#    - We could focus more on keeping customers without voicemail plans.
#    - Customers with voicemail plans are generally sticking around, which is good.

# %% [markdown]
# # Lets plot correlation matrix:

# %% [markdown]
# ### Multivariate Analysis:

# %%
mult = df[['Account Length', 'Area Code', 'Vmail_Message', 'Day_Mins', 'Day_Calls',
       'Day_Charge', 'Eve_Mins', 'Eve_Calls', 'Eve_Charge', 'Night_Mins',
       'Night_Calls', 'Night_Charge', 'International_Mins',
       'International_Charge','Churn']]

# %%
mult.corr()
# Out:
#                       Account Length  Area Code  Vmail_Message  Day_Mins  \
# Account Length              1.000000  -0.020394      -0.012983  0.002002
# Area Code                  -0.020394   1.000000      -0.002597 -0.018900
# Vmail_Message              -0.012983  -0.002597       1.000000  0.009028
# Day_Mins                    0.002002  -0.018900       0.009028  1.000000
# Day_Calls                   0.032783  -0.013179      -0.003846 -0.002823
# Day_Charge                  0.001999  -0.018903       0.009025  1.000000
# Eve_Mins                   -0.006778   0.011513       0.017872 -0.010260
# Eve_Calls                   0.015598  -0.011528      -0.006508  0.012990
# Eve_Charge                 -0.006775   0.011533       0.017878 -0.010268
# Night_Mins                 -0.002077   0.002794       0.004672  0.009604
# Night_Calls                -0.009482   0.015316       0.000889  0.005165
# Night_Charge               -0.002095   0.002782       0.004665  0.009591
# International_Mins          0.003483  -0.007292       0.005167 -0.012314
# International_Charge        0.003501  -0.007386       0.005202 -0.012261
# Churn                       0.018046   0.011995      -0.096884  0.202439
#
#                       Day_Calls  Day_Charge  Eve_Mins  Eve_Calls  Eve_Charge  \
# Account Length         0.032783    0.001999 -0.006778   0.015598   -0.006775
# Area Code             -0.013179   -0.018903  0.011513  -0.011528    0.011533
# Vmail_Message         -0.003846    0.009025  0.017872  -0.006508    0.017878
# Day_Mins              -0.002823    1.000000 -0.010260   0.012990   -0.010268
# Day_Calls              1.000000   -0.002821 -0.006430   0.003923   -0.006429
# Day_Charge            -0.002821    1.000000 -0.010255   0.012992   -0.010262
# Eve_Mins              -0.006430   -0.010255  1.000000   0.001135    1.000000
# Eve_Calls              0.003923    0.012992  0.001135   1.000000    0.001151
# Eve_Charge            -0.006429   -0.010262  1.000000   0.001151    1.000000
# Night_Mins             0.010730    0.009606 -0.018830   0.002610   -0.018839
# Night_Calls           -0.013299    0.005164  0.014226  -0.015463    0.014231
# Night_Charge           0.010724    0.009593 -0.018837   0.002624   -0.018846
# International_Mins     0.012951   -0.012315  0.000165  -0.002798    0.000163
# International_Charge   0.013055   -0.012262  0.000172  -0.002831    0.000170
# Churn                  0.016268    0.202434  0.087042   0.001943    0.087036
#
#                       Night_Mins  Night_Calls  Night_Charge  \
# Account Length         -0.002077    -0.009482     -0.002095
# Area Code               0.002794     0.015316      0.002782
# Vmail_Message           0.004672     0.000889      0.004665
# Day_Mins                0.009604     0.005165      0.009591
# Day_Calls               0.010730    -0.013299      0.010724
# Day_Charge              0.009606     0.005164      0.009593
# Eve_Mins               -0.018830     0.014226     -0.018837
# Eve_Calls               0.002610    -0.015463      0.002624
# Eve_Charge             -0.018839     0.014231     -0.018846
# Night_Mins              1.000000     0.025742      0.999999
# Night_Calls             0.025742     1.000000      0.025722
# Night_Charge            0.999999     0.025722      1.000000
# International_Mins     -0.004549    -0.006431     -0.004546
# International_Charge   -0.004500    -0.006439     -0.004497
# Churn                   0.043262    -0.006671      0.043260
#
#                       International_Mins  International_Charge     Churn
# Account Length                  0.003483              0.003501  0.018046
# Area Code                      -0.007292             -0.007386  0.011995
# Vmail_Message                   0.005167              0.005202 -0.096884
# Day_Mins                       -0.012314             -0.012261  0.202439
# Day_Calls                       0.012951              0.013055  0.016268
# Day_Charge                     -0.012315             -0.012262  0.202434
# Eve_Mins                        0.000165              0.000172  0.087042
# Eve_Calls                      -0.002798             -0.002831  0.001943
# Eve_Charge                      0.000163              0.000170  0.087036
# Night_Mins                     -0.004549             -0.004500  0.043262
# Night_Calls                    -0.006431             -0.006439 -0.006671
# Night_Charge                   -0.004546             -0.004497  0.043260
# International_Mins              1.000000              0.999993  0.064731
# International_Charge            0.999993              1.000000  0.064728
# Churn                           0.064731              0.064728  1.000000

# %% [markdown]
# # Insights :
#
#
#
# 1. **Strong Relationship between Usage and Charges:** Features related to usage, such as Day_Mins and Day_Charge, show a strong positive correlation, indicating that higher usage is associated with higher charges.
#
# 2. **Account Length's Limited Influence:** Account Length exhibits minimal correlation with other features, suggesting it may not strongly influence usage behavior or charges.
#
# 3. **Weak Correlation with Area Code:** The Area Code feature demonstrates weak correlations with other variables, indicating it may have limited impact on usage patterns or charges.
#
# 4. **Negative Correlation with Voicemail Messages:** There's a weak negative correlation between Voicemail Messages and Churn, implying that customers with more voicemail messages may be slightly less likely to churn, though the relationship is not strong.
#
# 5. **Moderate Correlation between International Features:** International_Mins and International_Charge exhibit a moderate positive correlation, suggesting that higher international call minutes are associated with higher international call charges.
#
# 6. **Limited Correlation with Night Usage:** Features related to nighttime usage (Night_Mins, Night_Calls, Night_Charge) show limited correlation with other variables, indicating nighttime usage may not strongly influence overall charges or churn.
#
# 7. **Eve Usage and Charges:** Eve_Mins and Eve_Charge display a moderate positive correlation, similar to daytime usage, indicating a relationship between evening usage and charges.
#
# 8. **Daytime Call Frequency:** Day_Calls shows a weak positive correlation with some usage and charge features, suggesting that higher daytime call frequency may be associated with higher usage and charges, though the relationship is not strong.
#
# 9. **Churn Correlations:** Churn exhibits varied correlations with other features, indicating that factors influencing churn may not be solely dependent on usage or charges, but potentially influenced by a combination of factors such as voicemail usage or international calling behavior.
#
#
#
#
#
#
# ### Based on the insights from the correlation matrix, the telecom company can consider the following decisions:
#
# 1. **Usage-Based Pricing:** Implement usage-based pricing plans that align with the strong relationship between usage and charges. This could involve offering flexible packages tailored to customers' usage patterns.
#
# 2. **Customer Retention Strategies:** Develop targeted retention strategies for customers with high voicemail usage, as they may be less likely to churn. This could involve providing incentives or personalized offers to encourage loyalty.
#
# 3. **International Calling Plans:** Offer competitive international calling plans, considering the moderate correlation between international call minutes and charges. This could attract customers who frequently make international calls.
#
# 4. **Enhanced Evening Services:** Enhance evening services or offers to capitalize on the moderate correlation between evening usage and charges. This could include promotional offers on evening calls or data usage during off-peak hours.
#
# 5. **Area-Specific Initiatives:** Explore area-specific initiatives or marketing campaigns based on the weak correlations with area codes. This could involve targeted promotions or services tailored to customers in specific geographic regions.
#
# 6. **Customer Communication:** Communicate transparently with customers about billing practices and the factors influencing charges, given the strong relationship between usage and charges. This could improve customer satisfaction and trust.
#
# 7. **Churn Prediction and Prevention:** Invest in churn prediction models that consider various factors beyond usage and charges, such as voicemail usage or international calling behavior. This could help identify at-risk customers and implement proactive retention9strategies.
#
# 8. **Customer Engagement Programs:** Launch customer engagement programs to encourage daytime usage and calls, leveraging the weak correlations between daytime call frequency and usage/charges. This could increase overall customer engagement and10satisfaction.
#
# 9. **Continuous Monitoring and Analysis:** Continuously monitor usage patterns and customer behavior to identify emerging trends and opportunities for improvement. This could involve regular analysis of customer data and feedback to inform strategic decisions and initiatives.
#
# By implementing these decisions, the telecom company can better meet the needs of its customers, improve retention rates, and drive business growth in a competitive market.

# %%
# sns.pairplot(mult, diag_kind='kde', hue = 'Churn')
# plt.show()

# %% [markdown]
# 1. **Creating Color Palette:** Generates a color palette with distinct colors for visualizing data trends in the heatmaps.
#
# 2. **Handling Missing Values:** Replaces any missing values in the DataFrame with zeros to ensure that the heatmaps are not disrupted by NaNs.
#
# 3. **Plotting Heatmaps:** Separates the data based on churn status, computes summary statistics for churned and non-churned customers, and then plots two side-by-side heatmaps to visualize the average values of each feature for each customer group.

# %%
# Improved color palette
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Ensure no NaN values which could disrupt the heatmaps
df.fillna(0, inplace=True)

# Split data based on 'Churn' column
churn = df[df['Churn'] == 1].describe().T
not_churn = df[df['Churn'] == 0].describe().T

# Plot settings
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
sns.heatmap(churn[['mean']], annot=True, cmap=cmap, linewidths=0.4, linecolor='black', cbar=True, fmt='.2f', ax=ax[0])
ax[0].set_title('Churned Customers')

sns.heatmap(not_churn[['mean']], annot=True, cmap=cmap, linewidths=0.4, linecolor='black', cbar=True, fmt='.2f', ax=ax[1])
ax[1].set_title('Not Churned Customers')

# Adjust layout for better readability and to prevent overlap
fig.tight_layout(pad=2)
plt.show()

# %%
# Calculating percentages for pie chart
churn_counts = df['Churn'].value_counts()
circle = [count / sum(churn_counts) * 100 for count in churn_counts]

# Colors for plotting
colors_pie = ['#ff9999','#66b3ff']  # Light red and light blue for pie chart
colors_bar = ['#ff4d4d', '#4da6ff']  # Brighter shades for bar chart

# Setting up the plots
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

# Pie chart
axs[0].pie(circle, labels=['Not-Churn Customer', 'Churn Customer'], autopct='%1.1f%%', startangle=90, explode=(0.1, 0), colors=colors_pie,
           wedgeprops={'edgecolor': 'black', 'linewidth': 1, 'antialiased': True}, textprops={'fontsize': 16})
axs[0].set_title('Churn vs. Not-Churn Percentage', fontsize=20, fontweight='bold', color='navy')

# Bar chart
sns.countplot(x='Churn', data=df, palette=colors_bar, edgecolor='black', ax=axs[1])
axs[1].set_title('Number of Churn vs. Not-Churn Customers', fontsize=20, fontweight='bold', color='navy')
axs[1].set_xlabel('Churn Status', fontsize=18, fontweight='bold')
axs[1].set_ylabel('Count', fontsize=18, fontweight='bold')
axs[1].set_xticklabels(['Not-Churn Customers', 'Churn Customers'], fontsize=15)

# Adding text labels above bars
for container in axs[1].containers:
    axs[1].bar_label(container, padding=3, fontsize=15, color='darkblue')

plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['State', 'Account Length', 'Area Code', 'Phone', 'International_Plan',
#        'Vmail_Plan', 'Vmail_Message', 'Day_Mins', 'Day_Calls', 'Day_Charge',
#        'Eve_Mins', 'Eve_Calls', 'Eve_Charge', 'Night_Mins', 'Night_Calls',
#        'Night_Charge', 'International_Mins', 'International_calls',
#        'International_Charge', 'CustServ_Calls', 'Churn'],
#       dtype='object')

# %%
# Categorical Varibles

# %%
# Define the columns to plot
columns_to_plot = ['Area Code', 'International_Plan', 'Vmail_Plan']

# Set up the plot grid
fig, axs = plt.subplots(nrows=1, ncols=len(columns_to_plot), figsize=(15, 5))  # All plots in a single row

# Colors for the plot
colors = ["#66b3ff", "#ff9999"]  # Churn: no and yes

for i, col in enumerate(columns_to_plot):
    ax = sns.countplot(x=col, data=df, hue='Churn', palette=colors, ax=axs[i])
    ax.set_title(f'Distribution of {col} by Churn', fontsize=15)
    ax.set_xlabel(col, fontsize=12)
    ax.set_ylabel('Count', fontsize=12)
    ax.legend(title='Churn Status', title_fontsize='13', fontsize='12')
    
    # Add text annotations for each bar for better clarity
    for p in ax.patches:
        ax.annotate(format(p.get_height(), '.0f'), 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha = 'center', va = 'center', 
                    xytext = (0, 10), 
                    textcoords = 'offset points', fontsize=10)

# Adjust layout to prevent overlap of titles, labels, etc.
plt.tight_layout()
plt.show()

# %%
# # Visualization: Distribution of numerical variables by churn status
# numerical_vars = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
# for col in numerical_vars:
#     sns.histplot(data=df, x=col,hue='Churn', kde=True,multiple ='stack' ,palette='bright')
#     plt.title(f'Distribution of {col} by Churn')
#     plt.show()

# %%
# Correlation analysis
correlation_matrix = df.corr()
plt.figure(figsize=(20, 15))
sns.heatmap(correlation_matrix, annot=True, cmap='YlGnBu', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Feature Engineering:

# %%
print(df.International_Plan.value_counts())
print("=="*10)
print(df.Vmail_Plan.value_counts())
# Out:
#  no     4171
#  yes     446
# Name: International_Plan, dtype: int64
# ====================
#  no     3381
#  yes    1236
# Name: Vmail_Plan, dtype: int64

# %% [markdown]
# Creating the 'Combined_Plans' feature captures interaction effects between international and voicemail plans, offering insights into nuanced customer behaviors. This segmentation enables tailored retention strategies, enhances predictive models' accuracy, and informs proactive churn mitigation efforts in the telecom industry.

# %%
df['Combine_Plans'] = df['International_Plan'] +'_'+df['Vmail_Plan']

# %%
df['Combine_Plans'] = df['Combine_Plans'].str.strip()

# %%
df['Combine_Plans'].value_counts()
# Out:
# no_ no      3060
# no_ yes     1111
# yes_ no      321
# yes_ yes     125
# Name: Combine_Plans, dtype: int64

# %%
df['Combine_Plans'] = df['Combine_Plans'].map({'no_ no':0,'no_ yes':1,'yes_ no':2,'yes_ yes':3 })

# %%
df['Combine_Plans'].value_counts()
# Out:
# 0    3060
# 1    1111
# 2     321
# 3     125
# Name: Combine_Plans, dtype: int64

# %% [markdown]
# The "Engagement Score" is made to measure how much customers interact with the telecom service. It includes things like voicemails, service calls, and international calls. By looking at this score, we can understand how involved customers are, which helps us figure out if they might leave and allows us to give them special attention to keep them happy and stay with us.

# %%
df.columns
# Out:
# Index(['State', 'Account Length', 'Area Code', 'Phone', 'International_Plan',
#        'Vmail_Plan', 'Vmail_Message', 'Day_Mins', 'Day_Calls', 'Day_Charge',
#        'Eve_Mins', 'Eve_Calls', 'Eve_Charge', 'Night_Mins', 'Night_Calls',
#        'Night_Charge', 'International_Mins', 'International_calls',
#        'International_Charge', 'CustServ_Calls', 'Churn', 'Combine_Plans'],
#       dtype='object')

# %%
# Calculate customer engagement score
df['Engagement_Score'] = df['Vmail_Message'] + df['CustServ_Calls'] + df['International_calls']

# %%
df['Total_charges'] = df['Day_Charge'] + df['Eve_Charge'] + df['Night_Charge'] + df['International_Charge']

# %%
df.head()
# Out:
#   State  Account Length  Area Code      Phone International_Plan Vmail_Plan  \
# 0    KS             128        415   382-4657                 no        yes
# 1    OH             107        415   371-7191                 no        yes
# 2    NJ             137        415   358-1921                 no         no
# 3    OH              84        408   375-9999                yes         no
# 4    OK              75        415   330-6626                yes         no
#
#    Vmail_Message  Day_Mins  Day_Calls  Day_Charge  Eve_Mins  Eve_Calls  \
# 0             25     265.1        110       45.07     197.4         99
# 1             26     161.6        123       27.47     195.5        103
# 2              0     243.4        114       41.38     121.2        110
# 3              0     299.4         71       50.90      61.9         88
# 4              0     166.7        113       28.34     148.3        122
#
#    Eve_Charge  Night_Mins  Night_Calls  Night_Charge  International_Mins  \
# 0       16.78       244.7           91         11.01                10.0
# 1       16.62       254.4          103         11.45                13.7
# 2       10.30       162.6          104          7.32                12.2
# 3        5.26       196.9           89          8.86                 6.6
# 4       12.61       186.9          121          8.41                10.1
#
#    International_calls  International_Charge  CustServ_Calls  Churn  \
# 0                    3                  2.70               1      0
# 1                    3                  3.70               1      0
# 2                    5                  3.29               0      0
# 3                    7                  1.78               2      0
# 4                    3                  2.73               3      0
#
#    Combine_Plans  Engagement_Score  Total_charges
# 0              1                29          75.56
# 1              1                30          59.24
# 2              0                 5          62.29
# 3              2                 9          66.80
# 4              2                 6          52.09

# %%
# sns.scatterplot(x = df.Total_charges, y  = df.Churn, hue  = df.Churn)

# %%
df['Total_mint']= df['Day_Mins'] + df['Eve_Mins'] +df['Night_Mins'] + df['International_Mins']

# %%
# sns.scatterplot(x = df.Total_charges, y =df.Churn, hue = df['Churn'])

# %%
df['Total_call'] = df['Day_Calls'] + df['Eve_Calls'] + df['Night_Calls'] +df['International_calls']

# %%
df.columns
# Out:
# Index(['State', 'Account Length', 'Area Code', 'Phone', 'International_Plan',
#        'Vmail_Plan', 'Vmail_Message', 'Day_Mins', 'Day_Calls', 'Day_Charge',
#        'Eve_Mins', 'Eve_Calls', 'Eve_Charge', 'Night_Mins', 'Night_Calls',
#        'Night_Charge', 'International_Mins', 'International_calls',
#        'International_Charge', 'CustServ_Calls', 'Churn', 'Combine_Plans',
#        'Engagement_Score', 'Total_charges', 'Total_mint', 'Total_call'],
#       dtype='object')

# %% [markdown]
# The "Charge Difference" feature is created to compare the total charges for local usage (day, evening, and night) with the charges for international calls, aiming to understand customer spending patterns and their potential impact on churn behavior.

# %%
# Create the new feature
df['Charge_Difference'] = df['Day_Charge'] + df['Eve_Charge'] + df['Night_Charge'] - df['International_Charge']

# %%
df.head()
# Out:
#   State  Account Length  Area Code      Phone International_Plan Vmail_Plan  \
# 0    KS             128        415   382-4657                 no        yes
# 1    OH             107        415   371-7191                 no        yes
# 2    NJ             137        415   358-1921                 no         no
# 3    OH              84        408   375-9999                yes         no
# 4    OK              75        415   330-6626                yes         no
#
#    Vmail_Message  Day_Mins  Day_Calls  Day_Charge  Eve_Mins  Eve_Calls  \
# 0             25     265.1        110       45.07     197.4         99
# 1             26     161.6        123       27.47     195.5        103
# 2              0     243.4        114       41.38     121.2        110
# 3              0     299.4         71       50.90      61.9         88
# 4              0     166.7        113       28.34     148.3        122
#
#    Eve_Charge  Night_Mins  Night_Calls  Night_Charge  International_Mins  \
# 0       16.78       244.7           91         11.01                10.0
# 1       16.62       254.4          103         11.45                13.7
# 2       10.30       162.6          104          7.32                12.2
# 3        5.26       196.9           89          8.86                 6.6
# 4       12.61       186.9          121          8.41                10.1
#
#    International_calls  International_Charge  CustServ_Calls  Churn  \
# 0                    3                  2.70               1      0
# 1                    3                  3.70               1      0
# 2                    5                  3.29               0      0
# 3                    7                  1.78               2      0
# 4                    3                  2.73               3      0
#
#    Combine_Plans  Engagement_Score  Total_charges  Total_mint  Total_call  \
# 0              1                29          75.56       717.2         303
# 1              1                30          59.24       625.2         332
# 2              0                 5          62.29       539.4         333
# 3              2                 9          66.80       564.8         255
# 4              2                 6          52.09       512.0         359
#
#    Charge_Difference
# 0              70.16
# 1              51.84
# 2              55.71
# 3              63.24
# 4              46.63

# %%
# sns.scatterplot(x = df.Total_call,y = df.Churn, hue = df.Churn)

# %%
created_features = df[['Combine_Plans','Engagement_Score','Total_charges','Total_mint', 'Total_call','Charge_Difference','Churn']]

# sns.pairplot(created_features, diag_kind='kde', hue = 'Churn')
# plt.show()

# %%
created_features.describe()
# Out:
#        Combine_Plans  Engagement_Score  Total_charges   Total_mint  \
# count    4617.000000       4617.000000    4617.000000  4617.000000
# mean        0.460905         13.850769      59.517390   591.779467
# std         0.741677         13.879512      10.366072    89.038048
# min         0.000000          0.000000      22.930000   284.300000
# 25%         0.000000          5.000000      52.480000   532.100000
# 50%         0.000000          7.000000      59.530000   592.700000
# 75%         1.000000         22.000000      66.470000   651.100000
# max         3.000000         61.000000      96.150000   885.000000
#
#         Total_call  Charge_Difference        Churn
# count  4617.000000        4617.000000  4617.000000
# mean    304.612086          53.965538     0.142084
# std      34.262059          10.383584     0.349174
# min     191.000000          16.710000     0.000000
# 25%     282.000000          46.790000     0.000000
# 50%     305.000000          54.000000     0.000000
# 75%     328.000000          60.770000     0.000000
# max     416.000000          89.370000     1.000000

# %%
created_features.corr()
# Out:
#                    Combine_Plans  Engagement_Score  Total_charges  Total_mint  \
# Combine_Plans           1.000000          0.566749       0.034157    0.024825
# Engagement_Score        0.566749          1.000000       0.014919    0.015205
# Total_charges           0.034157          0.014919       1.000000    0.889439
# Total_mint              0.024825          0.015205       0.889439    1.000000
# Total_call              0.007856          0.009115       0.015228    0.020993
# Charge_Difference       0.029372          0.013835       0.989705    0.884917
# Churn                   0.139403         -0.083283       0.229438    0.198725
#
#                    Total_call  Charge_Difference     Churn
# Combine_Plans        0.007856           0.029372  0.139403
# Engagement_Score     0.009115           0.013835 -0.083283
# Total_charges        0.015228           0.989705  0.229438
# Total_mint           0.020993           0.884917  0.198725
# Total_call           1.000000           0.014667  0.003395
# Charge_Difference    0.014667           1.000000  0.219770
# Churn                0.003395           0.219770  1.000000

# %%
corr_mat = created_features.corr()
plt.figure(figsize = (10, 10))
sns.heatmap(corr_mat, annot=True, fmt = '.2f')
plt.show()

# %% [markdown]
# # Insights :
#
# 1. Customers with certain combinations of plans tend to have higher engagement scores, suggesting that plan choices may influence customer involvement.
# 2. There's a strong correlation between total charges and total minutes, indicating that higher spending is associated with increased usage.
# 3. A positive correlation exists between churn and total charges, implying that customers who spend more may be more likely to leave.
# 4. Conversely, a negative correlation between churn and engagement score suggests that more engaged customers might be less likely to churn.
# 5. These insights highlight the importance of understanding customer behaviors and engagement levels for predicting churn and implementing effective retention strategies in the telecom industr
#
# ### Points to be focused for decision Making:i
#
# 1. **Engagement Boosters**: Focus on strategies that make customers more involved, like special offers and personalized perks.
#
# 2. **Extra Benefits**: Offer extra services or perks, especially to customers who spend a lot, to make them feel valued and less likely to leave.
#
# 3. **Tailored Packages**: Create customized plans based on what customers like, so they feel like they're getting exactly what they want.
#
# 4. **Proactive Support**: Reach out to customers before they have problems, so they know you care about their experience.
#
# 5. **Keep Improving**: Keep an eye on what's working and what's not, and keep tweaking your strategies to keep customers happy and loyal.d retention.

# %% [markdown]
# # Data Preprocessing :

# %%
df.isnull().sum()
# Out:
# State                   0
# Account Length          0
# Area Code               0
# Phone                   0
# International_Plan      0
# Vmail_Plan              0
# Vmail_Message           0
# Day_Mins                0
# Day_Calls               0
# Day_Charge              0
# Eve_Mins                0
# Eve_Calls               0
# Eve_Charge              0
# Night_Mins              0
# Night_Calls             0
# Night_Charge            0
# International_Mins      0
# International_calls     0
# International_Charge    0
# CustServ_Calls          0
# Churn                   0
# Combine_Plans           0
# Engagement_Score        0
# Total_charges           0
# Total_mint              0
# Total_call              0
# Charge_Difference       0
# dtype: int64

# %% [markdown]
# # Encoding of Categorical data:

# %%
categorical_column = []

for column in df.columns:
    if df[column].dtypes == object and len(df[column].unique())  <=200:
        categorical_column.append(column)
        print(f"Feature :{column}")
        print(f"{column} :{df[column].unique()}")
        print("****"*10)
        print()
# Out:
# Feature :State
# State :['KS' 'OH' 'NJ' 'OK' 'AL' 'MA' 'MO' 'LA' 'WV' 'IN' 'RI' 'IA' 'MT' 'NY'
#  'ID' 'VT' 'VA' 'TX' 'FL' 'CO' 'AZ' 'SC' 'NE' 'WY' 'HI' 'IL' 'NH' 'GA'
#  'AK' 'MD' 'AR' 'WI' 'OR' 'MI' 'DE' 'UT' 'CA' 'MN' 'SD' 'NC' 'WA' 'NM'
#  'NV' 'DC' 'KY' 'ME' 'MS' 'TN' 'PA' 'CT' 'ND']
# ****************************************
#
# Feature :International_Plan
# International_Plan :[' no' ' yes']
# ****************************************
#
# Feature :Vmail_Plan
# Vmail_Plan :[' yes' ' no']
# ****************************************

# %% [markdown]
# 1. **State:**
#    - Nominal: States do not have inherent order or rank. Each state is considered distinct without any implied hierarchy.
#
# 2. **International_Plan:**
#    - Nominal: The "International_Plan" feature consists of two categories ("yes" and "no"), without any inherent order.
#
# 3. **Vmail_Plan:**
#    - Nominal: Similarly, the "Vmail_Plan" feature contains two categories ("yes" and "no"), without any implied order.
#
# These features are all nominal because their categories are not ranked or ordered in any meaningful way.

# %%
nominal_feat = ['International_Plan', 'Vmail_Plan']

# %%
df = pd.get_dummies(df, columns=nominal_feat, drop_first = True)

# %%
df.drop(labels=['State','Phone'], axis = 1, inplace  = True)

# %% [markdown]
# # Outlier Handling:

# %%
plt.figure(figsize = (15, 20), facecolor = 'white')
plotnumber = 1
for column in df.columns:
    if plotnumber <= 24:
        plt.subplot(6,4, plotnumber)
        sns.boxplot(x = df[column], palette = 'rainbow')
        plt.title(f"Boxplot of {column}")
        plt.xlabel(column, fontsize = 10)
        plt.ylabel('Outliers', fontsize = 10)
        plotnumber += 1

plt.tight_layout()
plt.show()

# %%
outlier_info = {}

for column in df.columns:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    min_limit = Q1 - 1.5 * IQR
    max_limit = Q3 + 1.5 * IQR
    outlier_info[column] = {
        'Min_limit':min_limit,
        'Max_limit':max_limit,
        'IQR':IQR
    }

print()
for column, info in outlier_info.items():
    print(f"Max_limit & Min_limit & IQR : {column}")
    print(f"column : {column}")
    print(f"Min_limit : {info['Min_limit']}")
    print(f"Max_limit : {info['Max_limit']}")
    print(f"IQR : {info['IQR']}")
    print("**"*10)
    print()
# Out:
# Max_limit & Min_limit & IQR : Account Length
# column : Account Length
# Min_limit : -5.5
# Max_limit : 206.5
# IQR : 53.0
# ********************
#
# Max_limit & Min_limit & IQR : Area Code
# column : Area Code
# Min_limit : 255.0
# Max_limit : 663.0
# IQR : 102.0
# ********************
#
# Max_limit & Min_limit & IQR : Vmail_Message
# column : Vmail_Message
# Min_limit : -25.5
# Max_limit : 42.5
# IQR : 17.0
# ********************
#
# Max_limit & Min_limit & IQR : Day_Mins
# column : Day_Mins
# Min_limit : 34.049999999999955
# Max_limit : 326.45000000000005
# IQR : 73.10000000000002
# ********************
#
# Max_limit & Min_limit & IQR : Day_Calls
# column : Day_Calls
# Min_limit : 48.0
# Max_limit : 152.0
# IQR : 26.0
# ********************
#
# Max_limit & Min_limit & IQR : Day_Charge
# column : Day_Charge
# Min_limit : 5.785
# Max_limit : 55.504999999999995
# IQR : 12.43
# ********************
#
# Max_limit & Min_limit & IQR : Eve_Mins
# column : Eve_Mins
# Min_limit : 63.750000000000014
# Max_limit : 336.15
# IQR : 68.1
# ********************
#
# Max_limit & Min_limit & IQR : Eve_Calls
# column : Eve_Calls
# Min_limit : 46.5
# Max_limit : 154.5
# IQR : 27.0
# ********************
#
# Max_limit & Min_limit & IQR : Eve_Charge
# column : Eve_Charge
# Min_limit : 5.414999999999997
# Max_limit : 28.575000000000003
# IQR : 5.790000000000001
# ********************
#
# Max_limit & Min_limit & IQR : Night_Mins
# column : Night_Mins
# Min_limit : 65.39999999999998
# Max_limit : 336.6
# IQR : 67.80000000000001
# ********************
#
# Max_limit & Min_limit & IQR : Night_Calls
# column : Night_Calls
# Min_limit : 48.0
# Max_limit : 152.0
# IQR : 26.0
# ********************
#
# Max_limit & Min_limit & IQR : Night_Charge
# column : Night_Charge
# Min_limit : 2.9449999999999985
# Max_limit : 15.145000000000001
# IQR : 3.0500000000000007
# ********************
#
# Max_limit & Min_limit & IQR : International_Mins
# column : International_Mins
# Min_limit : 3.3499999999999996
# Max_limit : 17.35
# IQR : 3.5
# ********************
#
# Max_limit & Min_limit & IQR : International_calls
# column : International_calls
# Min_limit : -1.5
# Max_limit : 10.5
# IQR : 3.0
# ********************
#
# Max_limit & Min_limit & IQR : International_Charge
# column : International_Charge
# Min_limit : 0.8949999999999996
# Max_limit : 4.695
# IQR : 0.9500000000000002
# ********************
#
# Max_limit & Min_limit & IQR : CustServ_Calls
# column : CustServ_Calls
# Min_limit : -0.5
# Max_limit : 3.5
# IQR : 1.0
# ********************
#
# Max_limit & Min_limit & IQR : Churn
# column : Churn
# Min_limit : 0.0
# Max_limit : 0.0
# IQR : 0.0
# ********************
#
# Max_limit & Min_limit & IQR : Combine_Plans
# column : Combine_Plans
# Min_limit : -1.5
# Max_limit : 2.5
# IQR : 1.0
# ********************
#
# Max_limit & Min_limit & IQR : Engagement_Score
# column : Engagement_Score
# Min_limit : -20.5
# Max_limit : 47.5
# IQR : 17.0
# ********************
#
# Max_limit & Min_limit & IQR : Total_charges
# column : Total_charges
# Min_limit : 31.494999999999994
# Max_limit : 87.455
# IQR : 13.990000000000002
# ********************
#
# Max_limit & Min_limit & IQR : Total_mint
# column : Total_mint
# Min_limit : 353.6
# Max_limit : 829.6
# IQR : 119.0
# ********************
#
# Max_limit & Min_limit & IQR : Total_call
# column : Total_call
# Min_limit : 213.0
# Max_limit : 397.0
# IQR : 46.0
# ********************
#
# Max_limit & Min_limit & IQR : Charge_Difference
# column : Charge_Difference
# Min_limit : 25.819999999999975
# Max_limit : 81.74000000000002
# IQR : 13.980000000000011
# ********************
#
# Max_limit & Min_limit & IQR : International_Plan_ yes
# column : International_Plan_ yes
# Min_limit : 0.0
# Max_limit : 0.0
# IQR : 0.0
# ********************
#
# Max_limit & Min_limit & IQR : Vmail_Plan_ yes
# column : Vmail_Plan_ yes
# Min_limit : -1.5
# Max_limit : 2.5
# IQR : 1.0
# ********************

# %%
def identify_outlier(column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    min_limit = q1  - 1.5 * iqr
    max_limit = q3 + 1.5 * iqr
    outliers = df[(df[column] < min_limit) | (df[column] > max_limit)]
    return outliers

# %%
for column in df.columns:
    outliers = identify_outlier(column)
    outlier_count = len(outliers)
    if outlier_count >= 0:
        print(f"Features {column} has {outlier_count} has outliers")
        print("**"*10)
        print()
# Out:
# Features Account Length has 23 has outliers
# ********************
#
# Features Area Code has 0 has outliers
# ********************
#
# Features Vmail_Message has 51 has outliers
# ********************
#
# Features Day_Mins has 27 has outliers
# ********************
#
# Features Day_Calls has 34 has outliers
# ********************
#
# Features Day_Charge has 27 has outliers
# ********************
#
# Features Eve_Mins has 36 has outliers
# ********************
#
# Features Eve_Calls has 25 has outliers
# ********************
#
# Features Eve_Charge has 36 has outliers
# ********************
#
# Features Night_Mins has 36 has outliers
# ********************
#
# Features Night_Calls has 42 has outliers
# ********************
#
# Features Night_Charge has 36 has outliers
# ********************
#
# Features International_Mins has 65 has outliers
# ********************
#
# Features International_calls has 107 has outliers
# ********************
#
# Features International_Charge has 65 has outliers
# ********************
#
# Features CustServ_Calls has 368 has outliers
# ********************
#
# Features Churn has 656 has outliers
# ********************
#
# Features Combine_Plans has 125 has outliers
# ********************
#
# Features Engagement_Score has 86 has outliers
# ********************
#
# Features Total_charges has 38 has outliers
# ********************
#
# Features Total_mint has 33 has outliers
# ********************
#
# Features Total_call has 25 has outliers
# ********************
#
# Features Charge_Difference has 36 has outliers
# ********************
#
# Features International_Plan_ yes has 446 has outliers
# ********************
#
# Features Vmail_Plan_ yes has 0 has outliers
# ********************

# %%
continous_df = df[['Account Length', 'Area Code', 'Vmail_Message', 'Day_Mins', 'Day_Calls',
       'Day_Charge', 'Eve_Mins', 'Eve_Calls', 'Eve_Charge', 'Night_Mins',
       'Night_Calls', 'Night_Charge', 'International_Mins','Combine_Plans', 'Engagement_Score',
       'International_Charge','Total_charges', 'Total_mint', 'Total_call','Charge_Difference']]

# %%
for column in continous_df.columns:
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    min_limit = q1 - 1.5 * iqr
    max_limit = q3 + 1.5 * iqr
    df[column] = np.where((df[column] < min_limit) | (df[column] > max_limit),
                         df[column].mean(), df[column])

# %% [markdown]
# # Scaling of data:

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
l1 = df[['Churn','International_Plan_ yes','Vmail_Plan_ yes']]
x = df.drop(labels =l1 , axis= 1)

# %%
scaled = sc.fit_transform(x)

# %%
df2 = pd.DataFrame(scaled, columns = x.columns)

# %%
df3 = pd.concat([df2, l1], axis = 1)

# %%
df3.head()
# Out:
#    Account Length  Area Code  Vmail_Message  Day_Mins  Day_Calls  Day_Charge  \
# 0        0.722720  -0.521392       1.351459  1.609682   0.511573    1.609970
# 1        0.179710  -0.521392       1.428400 -0.359631   1.190031   -0.359920
# 2        0.955439  -0.521392      -0.572075  1.196792   0.720329    1.196964
# 3       -0.415015  -0.686941      -0.572075  2.262314  -1.523803    2.262496
# 4       -0.647733  -0.521392      -0.572075 -0.262592   0.668140   -0.262545
#
#    Eve_Mins  Eve_Calls  Eve_Charge  Night_Mins  Night_Calls  Night_Charge  \
# 0 -0.065280  -0.062273   -0.065095    0.905239    -0.461973      0.904496
# 1 -0.104269   0.145150   -0.103721    1.104535     0.166412      1.105388
# 2 -1.628923   0.508140   -1.629468   -0.781585     0.218777     -0.780259
# 3 -0.003122  -0.632686   -0.003123   -0.076858    -0.566703     -0.077136
# 4 -1.072825   1.130409   -1.071798   -0.282318     1.108988     -0.282594
#
#    International_Mins  International_calls  International_Charge  \
# 0           -0.126926            -0.583487             -0.127700
# 1            1.325692            -0.583487              1.326554
# 2            0.736793             0.230398              0.730310
# 3           -1.461764             1.044284             -1.465614
# 4           -0.087666            -0.583487             -0.084072
#
#    CustServ_Calls  Combine_Plans  Engagement_Score  Total_charges  Total_mint  \
# 0       -0.433885       0.998342          1.229019       1.607800    1.453045
# 1       -0.433885       0.998342          1.306596      -0.028016    0.386568
# 2       -1.199068      -0.644106         -0.632837       0.277697   -0.608037
# 3        0.331298       2.640789         -0.322528       0.729752   -0.313597
# 4        1.096480       2.640789         -0.555259      -0.744688   -0.925662
#
#    Total_call  Charge_Difference  Churn  International_Plan_ yes  \
# 0   -0.051199           1.617777      0                        0
# 1    0.814979          -0.212514      0                        0
# 2    0.844847           0.174125      0                        0
# 3   -1.484873           0.926423      0                        1
# 4    1.621421          -0.733028      0                        1
#
#    Vmail_Plan_ yes
# 0                1
# 1                1
# 2                0
# 3                0
# 4                0

# %%
df3.columns
# Out:
# Index(['Account Length', 'Area Code', 'Vmail_Message', 'Day_Mins', 'Day_Calls',
#        'Day_Charge', 'Eve_Mins', 'Eve_Calls', 'Eve_Charge', 'Night_Mins',
#        'Night_Calls', 'Night_Charge', 'International_Mins',
#        'International_calls', 'International_Charge', 'CustServ_Calls',
#        'Combine_Plans', 'Engagement_Score', 'Total_charges', 'Total_mint',
#        'Total_call', 'Charge_Difference', 'Churn', 'International_Plan_ yes',
#        'Vmail_Plan_ yes'],
#       dtype='object')

# %% [markdown]
# ### Feature_selection:

# %%
l2= df[['Account Length', 'Area Code']]

df4 =df3.drop(labels=l2, axis = 1)

# %%
df4.head()
# Out:
#    Vmail_Message  Day_Mins  Day_Calls  Day_Charge  Eve_Mins  Eve_Calls  \
# 0       1.351459  1.609682   0.511573    1.609970 -0.065280  -0.062273
# 1       1.428400 -0.359631   1.190031   -0.359920 -0.104269   0.145150
# 2      -0.572075  1.196792   0.720329    1.196964 -1.628923   0.508140
# 3      -0.572075  2.262314  -1.523803    2.262496 -0.003122  -0.632686
# 4      -0.572075 -0.262592   0.668140   -0.262545 -1.072825   1.130409
#
#    Eve_Charge  Night_Mins  Night_Calls  Night_Charge  International_Mins  \
# 0   -0.065095    0.905239    -0.461973      0.904496           -0.126926
# 1   -0.103721    1.104535     0.166412      1.105388            1.325692
# 2   -1.629468   -0.781585     0.218777     -0.780259            0.736793
# 3   -0.003123   -0.076858    -0.566703     -0.077136           -1.461764
# 4   -1.071798   -0.282318     1.108988     -0.282594           -0.087666
#
#    International_calls  International_Charge  CustServ_Calls  Combine_Plans  \
# 0            -0.583487             -0.127700       -0.433885       0.998342
# 1            -0.583487              1.326554       -0.433885       0.998342
# 2             0.230398              0.730310       -1.199068      -0.644106
# 3             1.044284             -1.465614        0.331298       2.640789
# 4            -0.583487             -0.084072        1.096480       2.640789
#
#    Engagement_Score  Total_charges  Total_mint  Total_call  Charge_Difference  \
# 0          1.229019       1.607800    1.453045   -0.051199           1.617777
# 1          1.306596      -0.028016    0.386568    0.814979          -0.212514
# 2         -0.632837       0.277697   -0.608037    0.844847           0.174125
# 3         -0.322528       0.729752   -0.313597   -1.484873           0.926423
# 4         -0.555259      -0.744688   -0.925662    1.621421          -0.733028
#
#    Churn  International_Plan_ yes  Vmail_Plan_ yes
# 0      0                        0                1
# 1      0                        0                1
# 2      0                        0                0
# 3      0                        1                0
# 4      0                        1                0

# %%
plt.figure(figsize = (20, 20), facecolor = 'white')
sns.heatmap(df4.corr(), annot = True, fmt = '.2f', cmap = 'RdYlGn')
plt.show()

# %% [markdown]
# # Model Building:

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
x = df4.drop('Churn', axis = 1)

# %%
x.head()
# Out:
#    Vmail_Message  Day_Mins  Day_Calls  Day_Charge  Eve_Mins  Eve_Calls  \
# 0       1.351459  1.609682   0.511573    1.609970 -0.065280  -0.062273
# 1       1.428400 -0.359631   1.190031   -0.359920 -0.104269   0.145150
# 2      -0.572075  1.196792   0.720329    1.196964 -1.628923   0.508140
# 3      -0.572075  2.262314  -1.523803    2.262496 -0.003122  -0.632686
# 4      -0.572075 -0.262592   0.668140   -0.262545 -1.072825   1.130409
#
#    Eve_Charge  Night_Mins  Night_Calls  Night_Charge  International_Mins  \
# 0   -0.065095    0.905239    -0.461973      0.904496           -0.126926
# 1   -0.103721    1.104535     0.166412      1.105388            1.325692
# 2   -1.629468   -0.781585     0.218777     -0.780259            0.736793
# 3   -0.003123   -0.076858    -0.566703     -0.077136           -1.461764
# 4   -1.071798   -0.282318     1.108988     -0.282594           -0.087666
#
#    International_calls  International_Charge  CustServ_Calls  Combine_Plans  \
# 0            -0.583487             -0.127700       -0.433885       0.998342
# 1            -0.583487              1.326554       -0.433885       0.998342
# 2             0.230398              0.730310       -1.199068      -0.644106
# 3             1.044284             -1.465614        0.331298       2.640789
# 4            -0.583487             -0.084072        1.096480       2.640789
#
#    Engagement_Score  Total_charges  Total_mint  Total_call  Charge_Difference  \
# 0          1.229019       1.607800    1.453045   -0.051199           1.617777
# 1          1.306596      -0.028016    0.386568    0.814979          -0.212514
# 2         -0.632837       0.277697   -0.608037    0.844847           0.174125
# 3         -0.322528       0.729752   -0.313597   -1.484873           0.926423
# 4         -0.555259      -0.744688   -0.925662    1.621421          -0.733028
#
#    International_Plan_ yes  Vmail_Plan_ yes
# 0                        0                1
# 1                        0                1
# 2                        0                0
# 3                        1                0
# 4                        1                0

# %%
y = df.Churn

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Churn, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y,test_size = 0.20, random_state=42)

# %%
x_train.shape, x_test.shape
# Out:
# ((3693, 22), (924, 22))

# %%
y_train.shape, y_test.shape
# Out:
# ((3693,), (924,))

# %%
sel_ = SelectFromModel(RandomForestClassifier(n_estimators=50, random_state=42))

# %%
sel_.fit(x_train, y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(n_estimators=50,
#                                                  random_state=42))

# %%
sel_.get_support()
# Out:
# array([False,  True, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False,  True,  True,
#        False,  True,  True, False])

# %%
selected_feat = x_train.columns[(sel_.get_support())]

# %%
selected_feat
# Out:
# Index(['Day_Mins', 'CustServ_Calls', 'Total_charges', 'Total_mint',
#        'Charge_Difference', 'International_Plan_ yes'],
#       dtype='object')

# %%
x1 = df4[['Day_Mins', 'Day_Charge', 'International_calls', 'CustServ_Calls',
       'Combine_Plans', 'Total_charges', 'Total_mint', 'Charge_Difference',
       'International_Plan_ yes']]

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()


x_sm, y_sm  = sm.fit_resample(x1, y)

# %%
x_sm.shape, y_sm.shape
# Out:
# ((7922, 9), (7922,))

# %%
x_train, x_test, y_train, y_test = train_test_split(x_sm,y_sm, stratify=y_sm, test_size = 0.20, random_state = 42 )

# %%
x_train.shape, x_test.shape
# Out:
# ((6337, 9), (1585, 9))

# %% [markdown]
# # DecisionTreeClassifier:

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_dt = dt.predict(x_test)

# %%
f1_score(y_test, y_dt)
# Out:
# 0.9202988792029888

# %%
cr = classification_report(y_test, y_dt)
print(f"DecisionTree Classification Report :\n{cr}")
# Out:
# DecisionTree Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       793
#            1       0.91      0.93      0.92       792
#
#     accuracy                           0.92      1585
#    macro avg       0.92      0.92      0.92      1585
# weighted avg       0.92      0.92      0.92      1585

# %% [markdown]
# # Hyperparameter Tuning for DecisionTreeClassifier:

# %%
params = {
    'criterion':['gini', 'entropy'],
    'splitter':['best','random'],
    'max_depth':list(range(1, 31)),
    'min_samples_split':[2,3,4,5,10],
    'min_samples_leaf':list(range(1, 21))
}
dt = DecisionTreeClassifier()

grid_cv = GridSearchCV(estimator=dt, param_grid=params, cv = 5, verbose = 2, scoring = 'f1', refit = True)

# %%
# grid_cv.fit(x_train, y_train)

# %%
# print(f"Best params grid_search_cv : \n{grid_cv.best_params_}")
# print()
# print(f"Best score gridsearchCv : \n{grid_cv.best_score_}")
# print()
# print(f"Best estimator of gridsearchCV : \n{grid_cv.best_estimator_}")

# %%
dt = DecisionTreeClassifier(criterion= 'entropy', 
                            max_depth = 25, 
                            min_samples_leaf = 1, 
                            min_samples_split = 3, 
                            splitter = 'best')

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=25, min_samples_split=3)

# %%
y_dt = dt.predict(x_test)

# %% [markdown]
# # Evaluation Metrics:

# %%
dt_eval_score = {
    "DecisionTreeClassifier f1_score ":f1_score(y_test,y_dt),
    "DecisionTreeClassifier Accuracy_score ":accuracy_score(y_test, y_dt),
    "DecisionTreeClassifier Recall_score ":recall_score(y_test, y_dt),
    "DecisionTreeClassifier Precision_score ":precision_score(y_test, y_dt)
}

for key, val in dt_eval_score.items():
    print("\t",key, ": ", val)
    print("\t","==="*10)
    print()
# Out:
# 	 DecisionTreeClassifier f1_score  :  0.9477658904971681
# 	 ==============================
#
# 	 DecisionTreeClassifier Accuracy_score  :  0.9476340694006309
# 	 ==============================
#
# 	 DecisionTreeClassifier Recall_score  :  0.9507575757575758
# 	 ==============================
#
# 	 DecisionTreeClassifier Precision_score  :  0.944792973651192
# 	 ==============================

# %%
cr = classification_report(y_test, y_dt)
print(f"classification report : \n{cr}")
# Out:
# classification report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       793
#            1       0.94      0.95      0.95       792
#
#     accuracy                           0.95      1585
#    macro avg       0.95      0.95      0.95      1585
# weighted avg       0.95      0.95      0.95      1585

# %% [markdown]
# # RandomForestClassifier:

# %%
rf = RandomForestClassifier(random_state=0)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred = rf.predict(x_test)

# %%
f1_score(y_test, y_pred)
# Out:
# 0.9539857420609202

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       793
#            1       0.98      0.93      0.95       792
#
#     accuracy                           0.96      1585
#    macro avg       0.96      0.96      0.96      1585
# weighted avg       0.96      0.96      0.96      1585

# %%
training_score = rf.predict(x_train)
f1_score(y_train, training_score)
# Out:
# 1.0

# %% [markdown]
# # Hyper Parameter Tuning:

# %%
params = {
    'n_estimators':[100, 200, 300, 400, 500],
    'max_features':['sqrt','log2'],
    'max_depth':[None, 10, 20, 30, 40, 50],
    'min_samples_split':[2,5,10],
    'min_samples_leaf':[1,2,4],
    'bootstrap':[True, False]
}

rt = RandomForestClassifier()

# grid_rf = GridSearchCV(estimator=rt, param_grid=params, scoring = 'f1', cv = 5,verbose= 2, refit=True)
grid_rd = RandomizedSearchCV(estimator=rt, param_distributions=params, scoring = 'f1', verbose = 2, random_state=42)

# %%
# grid_rd.fit(x_train, y_train)

# %%
# print(f"classes of grid_search : {grid_rd.classes_}")
# print()
# print(f"Best params of grid_rd : {grid_rd.best_params_}")
# print()
# print(f"Best estimators : {grid_rd.best_estimator_}")

# %%
rf_cl = RandomForestClassifier(n_estimators =  500,
min_samples_split =  2, 
min_samples_leaf = 1, 
max_features = 'log2', 
max_depth = 20, 
bootstrap =False)

# %%
rf_cl.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=20, max_features='log2',
#                        n_estimators=500)

# %%
y_rf_cl = rf_cl.predict(x_test)

# %%
f1_score(y_test, y_rf_cl)
# Out:
# 0.9625806451612903

# %%
rf_eval_score = {
    "RandomForestCalssifier  f1_score ":f1_score(y_test, y_rf_cl),
    "RandomForestClassifier Accuracy_score ":accuracy_score(y_test, y_rf_cl),
    "RandomForestClassifier Recall_score ":recall_score(y_test, y_rf_cl),
    "RandomForestClassifier Precision_score ":precision_score(y_test, y_rf_cl)
}

for key, val in rf_eval_score.items():
    print("\t", key,": ", val)
    print("\t","=="*10)
# Out:
# 	 RandomForestCalssifier  f1_score  :  0.9625806451612903
# 	 ====================
# 	 RandomForestClassifier Accuracy_score  :  0.9634069400630915
# 	 ====================
# 	 RandomForestClassifier Recall_score  :  0.9419191919191919
# 	 ====================
# 	 RandomForestClassifier Precision_score  :  0.9841688654353562
# 	 ====================

# %%
cr  = classification_report(y_test, y_rf_cl)
print(f"Classification report of RandomForestClassifier : \n{cr}")
# Out:
# Classification report of RandomForestClassifier :
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       793
#            1       0.98      0.94      0.96       792
#
#     accuracy                           0.96      1585
#    macro avg       0.96      0.96      0.96      1585
# weighted avg       0.96      0.96      0.96      1585

# %% [markdown]
# # Using ALL Variables:

# %%
# By using we will be able to create churn for all features

# %%
x.head(4)
# Out:
#    Vmail_Message  Day_Mins  Day_Calls  Day_Charge  Eve_Mins  Eve_Calls  \
# 0       1.351459  1.609682   0.511573    1.609970 -0.065280  -0.062273
# 1       1.428400 -0.359631   1.190031   -0.359920 -0.104269   0.145150
# 2      -0.572075  1.196792   0.720329    1.196964 -1.628923   0.508140
# 3      -0.572075  2.262314  -1.523803    2.262496 -0.003122  -0.632686
#
#    Eve_Charge  Night_Mins  Night_Calls  Night_Charge  International_Mins  \
# 0   -0.065095    0.905239    -0.461973      0.904496           -0.126926
# 1   -0.103721    1.104535     0.166412      1.105388            1.325692
# 2   -1.629468   -0.781585     0.218777     -0.780259            0.736793
# 3   -0.003123   -0.076858    -0.566703     -0.077136           -1.461764
#
#    International_calls  International_Charge  CustServ_Calls  Combine_Plans  \
# 0            -0.583487             -0.127700       -0.433885       0.998342
# 1            -0.583487              1.326554       -0.433885       0.998342
# 2             0.230398              0.730310       -1.199068      -0.644106
# 3             1.044284             -1.465614        0.331298       2.640789
#
#    Engagement_Score  Total_charges  Total_mint  Total_call  Charge_Difference  \
# 0          1.229019       1.607800    1.453045   -0.051199           1.617777
# 1          1.306596      -0.028016    0.386568    0.814979          -0.212514
# 2         -0.632837       0.277697   -0.608037    0.844847           0.174125
# 3         -0.322528       0.729752   -0.313597   -1.484873           0.926423
#
#    International_Plan_ yes  Vmail_Plan_ yes
# 0                        0                1
# 1                        0                1
# 2                        0                0
# 3                        1                0

# %%
y.sample(4)
# Out:
# 2151    0
# 157     0
# 349     1
# 3613    1
# Name: Churn, dtype: int64

# %%
x_train,x_test, y_train, y_test = train_test_split(x,y, stratify=y, test_size =0.20, random_state = 42)

# %%
x_train.shape, x_test.shape
# Out:
# ((3693, 22), (924, 22))

# %%
y_train.shape, y_test.shape
# Out:
# ((3693,), (924,))

# %%
Counter(y_train)
# Out:
# Counter({0: 3168, 1: 525})

# %%
x_train_sm, y_train_sm = sm.fit_resample(x_train, y_train)

# %%
Counter(y_train_sm)
# Out:
# Counter({0: 3168, 1: 3168})

# %% [markdown]
# ## To enhance the efficiency and organization of executing machine learning models, it's advisable to employ a for loop for iterative model execution.

# %%
rf = RandomForestClassifier()
ad = AdaBoostClassifier()
an = MLPClassifier(
    activation = 'tanh',
    hidden_layer_sizes = (100,),
    learning_rate='constant',
    solver = 'sgd'
)

lg = LGBMClassifier(learning_rate=0.3,n_estimators=100, num_leaves = 20)
xgb = XGBClassifier()
gb = GradientBoostingClassifier()
lr= LogisticRegression()
svc= SVC(C = 0.1, gamma = 0.01, kernel='linear', random_state=42)
dt = DecisionTreeClassifier()
ct = CatBoostClassifier()
bn = BernoulliNB()

# %%
lst = [rf, ad, an, lg, xgb, gb, lr, svc,dt,ct,bn]

# acc = []
model = []

for i in lst:
    print("*"*20, i , "*"*20)
    i.fit(x_train, y_train)
    y_pred = i.predict(x_test)
    print(classification_report(y_test, y_pred))
    print()
    f1 = f1_score(y_test, y_pred)
    print("F1_score ",f1)
    print()
    acc = accuracy_score(y_test, y_pred)
    print("Accuracy_score ",acc)
    print()
    print("_"*200)
    model.append(i)
# Out:
# ******************** RandomForestClassifier() ********************
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       793
#            1       0.98      0.82      0.89       131
#
#     accuracy                           0.97       924
#    macro avg       0.98      0.91      0.94       924
# weighted avg       0.97      0.97      0.97       924
#
#
# F1_score  0.8916666666666667
#
# Accuracy_score  0.9718614718614719
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# ******************** AdaBoostClassifier() ********************
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       793
#            1       0.75      0.61      0.68       131
#
#     accuracy                           0.92       924
#    macro avg       0.85      0.79      0.81       924
# weighted avg       0.91      0.92      0.91       924
#
#
# F1_score  0.6751054852320675
#
# Accuracy_score  0.9166666666666666
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# ******************** MLPClassifier(activation='tanh', solver='sgd') ********************
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94       793
#            1       0.83      0.37      0.51       131
#
#     accuracy                           0.90       924
#    macro avg       0.87      0.68      0.73       924
# weighted avg       0.89      0.90      0.88       924
#
#
# F1_score  0.5079365079365079
#
# Accuracy_score  0.8993506493506493
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# ******************** LGBMClassifier(learning_rate=0.3, num_leaves=20) ********************
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 525, number of negative: 3168
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000517 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3174
# [LightGBM] [Info] Number of data points in the train set: 3693, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.142161 -> initscore=-1.797457
# [LightGBM] [Info] Start training from score -1.797457
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       793
#            1       0.97      0.83      0.90       131
#
#     accuracy                           0.97       924
#    macro avg       0.97      0.91      0.94       924
# weighted avg       0.97      0.97      0.97       924
#
#
# F1_score  0.897119341563786
#
# Accuracy_score  0.9729437229437229
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# ******************** XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...) ********************
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       793
#            1       0.97      0.82      0.89       131
#
#     accuracy                           0.97       924
#    macro avg       0.97      0.91      0.94       924
# weighted avg       0.97      0.97      0.97       924
#
#
# F1_score  0.8925619834710744
#
# Accuracy_score  0.9718614718614719
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# ******************** GradientBoostingClassifier() ********************
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       793
#            1       0.98      0.82      0.90       131
#
#     accuracy                           0.97       924
#    macro avg       0.98      0.91      0.94       924
# weighted avg       0.97      0.97      0.97       924
#
#
# F1_score  0.8962655601659751
#
# Accuracy_score  0.9729437229437229
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# ******************** LogisticRegression() ********************
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92       793
#            1       0.47      0.16      0.24       131
#
#     accuracy                           0.85       924
#    macro avg       0.67      0.57      0.58       924
# weighted avg       0.82      0.85      0.82       924
#
#
# F1_score  0.23863636363636365
#
# Accuracy_score  0.854978354978355
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# ******************** SVC(C=0.1, gamma=0.01, kernel='linear', random_state=42) ********************
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       793
#            1       0.00      0.00      0.00       131
#
#     accuracy                           0.86       924
#    macro avg       0.43      0.50      0.46       924
# weighted avg       0.74      0.86      0.79       924
#
#
# F1_score  0.0
#
# Accuracy_score  0.8582251082251082
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# ******************** DecisionTreeClassifier() ********************
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       793
#            1       0.70      0.83      0.76       131
#
#     accuracy                           0.93       924
#    macro avg       0.84      0.89      0.86       924
# weighted avg       0.93      0.93      0.93       924
#
#
# F1_score  0.7622377622377622
#
# Accuracy_score  0.9264069264069265
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# ******************** <catboost.core.CatBoostClassifier object at 0x000001C25C346510> ********************
# Learning rate set to 0.017997
# 0:	learn: 0.6689995	total: 7.44ms	remaining: 7.44s
# 1:	learn: 0.6449463	total: 13.8ms	remaining: 6.91s
# 2:	learn: 0.6221317	total: 20.4ms	remaining: 6.78s
# 3:	learn: 0.6013325	total: 27.3ms	remaining: 6.79s
# 4:	learn: 0.5804515	total: 33.7ms	remaining: 6.71s
# 5:	learn: 0.5646369	total: 40.4ms	remaining: 6.69s
# 6:	learn: 0.5452086	total: 47.2ms	remaining: 6.7s
# 7:	learn: 0.5323311	total: 53.9ms	remaining: 6.68s
# 8:	learn: 0.5146331	total: 60.6ms	remaining: 6.67s
# 9:	learn: 0.5009990	total: 67.2ms	remaining: 6.65s
# 10:	learn: 0.4849645	total: 74ms	remaining: 6.65s
# 11:	learn: 0.4746660	total: 80.3ms	remaining: 6.61s
# 12:	learn: 0.4602702	total: 88.8ms	remaining: 6.74s
# 13:	learn: 0.4456572	total: 96.7ms	remaining: 6.81s
# 14:	learn: 0.4308976	total: 104ms	remaining: 6.85s
# 15:	learn: 0.4213853	total: 114ms	remaining: 6.98s
# 16:	learn: 0.4114336	total: 121ms	remaining: 6.97s
# 17:	learn: 0.4018289	total: 127ms	remaining: 6.95s
# 18:	learn: 0.3930459	total: 134ms	remaining: 6.92s
# 19:	learn: 0.3799210	total: 141ms	remaining: 6.89s
# 20:	learn: 0.3697062	total: 147ms	remaining: 6.87s
# 21:	learn: 0.3597453	total: 154ms	remaining: 6.85s
# 22:	learn: 0.3519976	total: 161ms	remaining: 6.82s
# 23:	learn: 0.3436848	total: 167ms	remaining: 6.8s
# 24:	learn: 0.3369265	total: 174ms	remaining: 6.77s
# 25:	learn: 0.3302427	total: 180ms	remaining: 6.75s
# 26:	learn: 0.3243811	total: 187ms	remaining: 6.73s
# 27:	learn: 0.3187489	total: 193ms	remaining: 6.71s
# 28:	learn: 0.3101721	total: 200ms	remaining: 6.69s
# 29:	learn: 0.3023032	total: 207ms	remaining: 6.68s
# 30:	learn: 0.2951488	total: 213ms	remaining: 6.66s
# 31:	learn: 0.2903812	total: 220ms	remaining: 6.64s
# 32:	learn: 0.2834363	total: 226ms	remaining: 6.63s
# 33:	learn: 0.2793675	total: 233ms	remaining: 6.61s
# 34:	learn: 0.2749188	total: 239ms	remaining: 6.59s
# 35:	learn: 0.2699554	total: 246ms	remaining: 6.58s
# 36:	learn: 0.2662122	total: 252ms	remaining: 6.57s
# 37:	learn: 0.2622081	total: 259ms	remaining: 6.55s
# 38:	learn: 0.2584241	total: 266ms	remaining: 6.54s
# 39:	learn: 0.2546940	total: 272ms	remaining: 6.53s
# 40:	learn: 0.2502917	total: 279ms	remaining: 6.52s
# 41:	learn: 0.2467498	total: 286ms	remaining: 6.51s
# 42:	learn: 0.2425791	total: 292ms	remaining: 6.5s
# 43:	learn: 0.2391271	total: 299ms	remaining: 6.49s
# 44:	learn: 0.2357758	total: 307ms	remaining: 6.51s
# 45:	learn: 0.2331474	total: 314ms	remaining: 6.52s
# 46:	learn: 0.2286850	total: 322ms	remaining: 6.53s
# 47:	learn: 0.2245357	total: 331ms	remaining: 6.57s
# 48:	learn: 0.2214408	total: 338ms	remaining: 6.56s
# 49:	learn: 0.2187972	total: 345ms	remaining: 6.55s
# 50:	learn: 0.2159286	total: 351ms	remaining: 6.54s
# 51:	learn: 0.2128003	total: 358ms	remaining: 6.54s
# 52:	learn: 0.2104224	total: 365ms	remaining: 6.52s
# 53:	learn: 0.2074971	total: 372ms	remaining: 6.51s
# 54:	learn: 0.2045046	total: 379ms	remaining: 6.51s
# 55:	learn: 0.2016622	total: 386ms	remaining: 6.51s
# 56:	learn: 0.1994515	total: 393ms	remaining: 6.5s
# 57:	learn: 0.1970270	total: 399ms	remaining: 6.49s
# 58:	learn: 0.1942287	total: 406ms	remaining: 6.48s
# 59:	learn: 0.1913334	total: 413ms	remaining: 6.46s
# 60:	learn: 0.1890645	total: 419ms	remaining: 6.45s
# 61:	learn: 0.1866617	total: 426ms	remaining: 6.44s
# 62:	learn: 0.1844322	total: 432ms	remaining: 6.43s
# 63:	learn: 0.1829603	total: 439ms	remaining: 6.42s
# 64:	learn: 0.1809620	total: 445ms	remaining: 6.4s
# 65:	learn: 0.1786119	total: 452ms	remaining: 6.39s
# 66:	learn: 0.1763937	total: 458ms	remaining: 6.38s
# 67:	learn: 0.1747587	total: 465ms	remaining: 6.37s
# 68:	learn: 0.1730599	total: 472ms	remaining: 6.37s
# 69:	learn: 0.1719604	total: 480ms	remaining: 6.38s
# 70:	learn: 0.1705397	total: 487ms	remaining: 6.38s
# 71:	learn: 0.1688985	total: 495ms	remaining: 6.37s
# 72:	learn: 0.1677843	total: 502ms	remaining: 6.37s
# 73:	learn: 0.1666003	total: 509ms	remaining: 6.37s
# 74:	learn: 0.1651777	total: 517ms	remaining: 6.37s
# 75:	learn: 0.1637757	total: 524ms	remaining: 6.37s
# 76:	learn: 0.1627729	total: 533ms	remaining: 6.39s
# 77:	learn: 0.1619454	total: 540ms	remaining: 6.39s
# 78:	learn: 0.1607050	total: 547ms	remaining: 6.38s
# 79:	learn: 0.1601108	total: 554ms	remaining: 6.37s
# 80:	learn: 0.1584505	total: 561ms	remaining: 6.36s
# 81:	learn: 0.1570440	total: 567ms	remaining: 6.35s
# 82:	learn: 0.1561153	total: 574ms	remaining: 6.34s
# 83:	learn: 0.1551836	total: 581ms	remaining: 6.33s
# 84:	learn: 0.1539619	total: 587ms	remaining: 6.32s
# 85:	learn: 0.1533816	total: 594ms	remaining: 6.31s
# 86:	learn: 0.1525994	total: 599ms	remaining: 6.29s
# 87:	learn: 0.1515098	total: 606ms	remaining: 6.28s
# 88:	learn: 0.1505402	total: 613ms	remaining: 6.27s
# 89:	learn: 0.1496271	total: 619ms	remaining: 6.26s
# 90:	learn: 0.1488778	total: 626ms	remaining: 6.25s
# 91:	learn: 0.1483595	total: 633ms	remaining: 6.24s
# 92:	learn: 0.1473238	total: 640ms	remaining: 6.24s
# 93:	learn: 0.1462228	total: 646ms	remaining: 6.23s
# 94:	learn: 0.1455255	total: 653ms	remaining: 6.22s
# 95:	learn: 0.1447864	total: 659ms	remaining: 6.21s
# 96:	learn: 0.1442071	total: 666ms	remaining: 6.2s
# 97:	learn: 0.1435264	total: 672ms	remaining: 6.19s
# 98:	learn: 0.1431748	total: 679ms	remaining: 6.18s
# 99:	learn: 0.1424048	total: 686ms	remaining: 6.17s
# 100:	learn: 0.1414198	total: 692ms	remaining: 6.16s
# 101:	learn: 0.1408755	total: 699ms	remaining: 6.15s
# 102:	learn: 0.1402255	total: 707ms	remaining: 6.15s
# 103:	learn: 0.1399427	total: 714ms	remaining: 6.15s
# 104:	learn: 0.1392581	total: 722ms	remaining: 6.15s
# 105:	learn: 0.1388246	total: 731ms	remaining: 6.16s
# 106:	learn: 0.1380290	total: 738ms	remaining: 6.16s
# 107:	learn: 0.1373174	total: 744ms	remaining: 6.15s
# 108:	learn: 0.1367325	total: 751ms	remaining: 6.14s
# 109:	learn: 0.1364488	total: 758ms	remaining: 6.13s
# 110:	learn: 0.1361481	total: 764ms	remaining: 6.12s
# 111:	learn: 0.1355326	total: 771ms	remaining: 6.11s
# 112:	learn: 0.1349354	total: 777ms	remaining: 6.1s
# 113:	learn: 0.1344339	total: 785ms	remaining: 6.1s
# 114:	learn: 0.1340258	total: 792ms	remaining: 6.1s
# 115:	learn: 0.1335353	total: 799ms	remaining: 6.09s
# 116:	learn: 0.1331644	total: 806ms	remaining: 6.08s
# 117:	learn: 0.1326317	total: 812ms	remaining: 6.07s
# 118:	learn: 0.1322383	total: 819ms	remaining: 6.06s
# 119:	learn: 0.1315856	total: 826ms	remaining: 6.05s
# 120:	learn: 0.1310797	total: 832ms	remaining: 6.05s
# 121:	learn: 0.1305703	total: 839ms	remaining: 6.04s
# 122:	learn: 0.1301312	total: 845ms	remaining: 6.03s
# 123:	learn: 0.1296939	total: 852ms	remaining: 6.02s
# 124:	learn: 0.1293962	total: 859ms	remaining: 6.01s
# 125:	learn: 0.1291336	total: 865ms	remaining: 6s
# 126:	learn: 0.1285913	total: 872ms	remaining: 5.99s
# 127:	learn: 0.1281350	total: 879ms	remaining: 5.99s
# 128:	learn: 0.1274502	total: 885ms	remaining: 5.98s
# 129:	learn: 0.1270104	total: 892ms	remaining: 5.97s
# 130:	learn: 0.1267180	total: 899ms	remaining: 5.96s
# 131:	learn: 0.1264351	total: 907ms	remaining: 5.96s
# 132:	learn: 0.1261986	total: 915ms	remaining: 5.96s
# 133:	learn: 0.1259183	total: 922ms	remaining: 5.96s
# 134:	learn: 0.1257881	total: 930ms	remaining: 5.96s
# 135:	learn: 0.1255609	total: 938ms	remaining: 5.96s
# 136:	learn: 0.1251568	total: 945ms	remaining: 5.95s
# 137:	learn: 0.1248332	total: 952ms	remaining: 5.95s
# 138:	learn: 0.1245765	total: 959ms	remaining: 5.94s
# 139:	learn: 0.1242577	total: 965ms	remaining: 5.93s
# 140:	learn: 0.1238721	total: 972ms	remaining: 5.92s
# 141:	learn: 0.1234601	total: 979ms	remaining: 5.91s
# 142:	learn: 0.1232636	total: 985ms	remaining: 5.9s
# 143:	learn: 0.1230520	total: 992ms	remaining: 5.9s
# 144:	learn: 0.1227427	total: 999ms	remaining: 5.89s
# 145:	learn: 0.1222835	total: 1s	remaining: 5.88s
# 146:	learn: 0.1220048	total: 1.01s	remaining: 5.87s
# 147:	learn: 0.1217679	total: 1.02s	remaining: 5.86s
# 148:	learn: 0.1215698	total: 1.02s	remaining: 5.86s
# 149:	learn: 0.1214474	total: 1.03s	remaining: 5.85s
# 150:	learn: 0.1211786	total: 1.04s	remaining: 5.84s
# 151:	learn: 0.1208548	total: 1.04s	remaining: 5.83s
# 152:	learn: 0.1205472	total: 1.05s	remaining: 5.82s
# 153:	learn: 0.1203745	total: 1.06s	remaining: 5.81s
# 154:	learn: 0.1200393	total: 1.06s	remaining: 5.8s
# 155:	learn: 0.1198773	total: 1.07s	remaining: 5.8s
# 156:	learn: 0.1196949	total: 1.07s	remaining: 5.77s
# 157:	learn: 0.1194291	total: 1.08s	remaining: 5.77s
# 158:	learn: 0.1192335	total: 1.09s	remaining: 5.76s
# 159:	learn: 0.1190726	total: 1.09s	remaining: 5.75s
# 160:	learn: 0.1189922	total: 1.1s	remaining: 5.73s
# 161:	learn: 0.1188147	total: 1.11s	remaining: 5.73s
# 162:	learn: 0.1186827	total: 1.11s	remaining: 5.72s
# 163:	learn: 0.1185393	total: 1.12s	remaining: 5.72s
# 164:	learn: 0.1181007	total: 1.13s	remaining: 5.72s
# 165:	learn: 0.1179914	total: 1.14s	remaining: 5.73s
# 166:	learn: 0.1176678	total: 1.15s	remaining: 5.72s
# 167:	learn: 0.1175139	total: 1.15s	remaining: 5.71s
# 168:	learn: 0.1172897	total: 1.16s	remaining: 5.71s
# 169:	learn: 0.1170857	total: 1.17s	remaining: 5.7s
# 170:	learn: 0.1166150	total: 1.17s	remaining: 5.69s
# 171:	learn: 0.1165032	total: 1.18s	remaining: 5.68s
# 172:	learn: 0.1163127	total: 1.19s	remaining: 5.67s
# 173:	learn: 0.1160997	total: 1.19s	remaining: 5.67s
# 174:	learn: 0.1158936	total: 1.2s	remaining: 5.66s
# 175:	learn: 0.1156796	total: 1.21s	remaining: 5.65s
# 176:	learn: 0.1154599	total: 1.21s	remaining: 5.64s
# 177:	learn: 0.1153727	total: 1.22s	remaining: 5.63s
# 178:	learn: 0.1152964	total: 1.23s	remaining: 5.63s
# 179:	learn: 0.1149655	total: 1.23s	remaining: 5.62s
# 180:	learn: 0.1148517	total: 1.24s	remaining: 5.61s
# 181:	learn: 0.1146589	total: 1.25s	remaining: 5.6s
# 182:	learn: 0.1143853	total: 1.25s	remaining: 5.59s
# 183:	learn: 0.1142358	total: 1.26s	remaining: 5.59s
# 184:	learn: 0.1140470	total: 1.27s	remaining: 5.58s
# 185:	learn: 0.1139488	total: 1.27s	remaining: 5.57s
# 186:	learn: 0.1137366	total: 1.28s	remaining: 5.56s
# 187:	learn: 0.1136067	total: 1.29s	remaining: 5.55s
# 188:	learn: 0.1134928	total: 1.29s	remaining: 5.55s
# 189:	learn: 0.1133213	total: 1.3s	remaining: 5.54s
# 190:	learn: 0.1132266	total: 1.31s	remaining: 5.54s
# 191:	learn: 0.1130703	total: 1.31s	remaining: 5.53s
# 192:	learn: 0.1128439	total: 1.32s	remaining: 5.53s
# 193:	learn: 0.1125891	total: 1.33s	remaining: 5.53s
# 194:	learn: 0.1124298	total: 1.34s	remaining: 5.53s
# 195:	learn: 0.1123544	total: 1.34s	remaining: 5.52s
# 196:	learn: 0.1121541	total: 1.35s	remaining: 5.51s
# 197:	learn: 0.1119614	total: 1.36s	remaining: 5.51s
# 198:	learn: 0.1117521	total: 1.37s	remaining: 5.5s
# 199:	learn: 0.1116610	total: 1.37s	remaining: 5.49s
# 200:	learn: 0.1115754	total: 1.38s	remaining: 5.48s
# 201:	learn: 0.1114921	total: 1.39s	remaining: 5.47s
# 202:	learn: 0.1113825	total: 1.39s	remaining: 5.47s
# 203:	learn: 0.1112920	total: 1.4s	remaining: 5.46s
# 204:	learn: 0.1112146	total: 1.41s	remaining: 5.45s
# 205:	learn: 0.1109903	total: 1.41s	remaining: 5.45s
# 206:	learn: 0.1107460	total: 1.42s	remaining: 5.44s
# 207:	learn: 0.1104981	total: 1.43s	remaining: 5.43s
# 208:	learn: 0.1103710	total: 1.43s	remaining: 5.42s
# 209:	learn: 0.1103203	total: 1.44s	remaining: 5.41s
# 210:	learn: 0.1102561	total: 1.45s	remaining: 5.41s
# 211:	learn: 0.1101648	total: 1.45s	remaining: 5.4s
# 212:	learn: 0.1100632	total: 1.46s	remaining: 5.39s
# 213:	learn: 0.1099503	total: 1.47s	remaining: 5.39s
# 214:	learn: 0.1098230	total: 1.47s	remaining: 5.38s
# 215:	learn: 0.1097496	total: 1.48s	remaining: 5.37s
# 216:	learn: 0.1096501	total: 1.49s	remaining: 5.36s
# 217:	learn: 0.1095084	total: 1.49s	remaining: 5.36s
# 218:	learn: 0.1093843	total: 1.5s	remaining: 5.35s
# 219:	learn: 0.1092165	total: 1.51s	remaining: 5.34s
# 220:	learn: 0.1089647	total: 1.51s	remaining: 5.34s
# 221:	learn: 0.1088536	total: 1.52s	remaining: 5.34s
# 222:	learn: 0.1086819	total: 1.53s	remaining: 5.33s
# 223:	learn: 0.1086249	total: 1.54s	remaining: 5.33s
# 224:	learn: 0.1084028	total: 1.55s	remaining: 5.33s
# 225:	learn: 0.1082807	total: 1.56s	remaining: 5.33s
# 226:	learn: 0.1082176	total: 1.56s	remaining: 5.32s
# 227:	learn: 0.1081379	total: 1.57s	remaining: 5.32s
# 228:	learn: 0.1080404	total: 1.58s	remaining: 5.31s
# 229:	learn: 0.1078440	total: 1.58s	remaining: 5.3s
# 230:	learn: 0.1076828	total: 1.59s	remaining: 5.29s
# 231:	learn: 0.1076123	total: 1.6s	remaining: 5.28s
# 232:	learn: 0.1074016	total: 1.6s	remaining: 5.28s
# 233:	learn: 0.1072790	total: 1.61s	remaining: 5.27s
# 234:	learn: 0.1071476	total: 1.61s	remaining: 5.26s
# 235:	learn: 0.1070651	total: 1.62s	remaining: 5.25s
# 236:	learn: 0.1069323	total: 1.63s	remaining: 5.25s
# 237:	learn: 0.1068702	total: 1.64s	remaining: 5.24s
# 238:	learn: 0.1067961	total: 1.64s	remaining: 5.23s
# 239:	learn: 0.1067058	total: 1.65s	remaining: 5.22s
# 240:	learn: 0.1066223	total: 1.66s	remaining: 5.21s
# 241:	learn: 0.1064461	total: 1.66s	remaining: 5.21s
# 242:	learn: 0.1063629	total: 1.67s	remaining: 5.2s
# 243:	learn: 0.1062003	total: 1.68s	remaining: 5.19s
# 244:	learn: 0.1061358	total: 1.68s	remaining: 5.18s
# 245:	learn: 0.1059711	total: 1.69s	remaining: 5.18s
# 246:	learn: 0.1058275	total: 1.7s	remaining: 5.17s
# 247:	learn: 0.1056564	total: 1.7s	remaining: 5.16s
# 248:	learn: 0.1054961	total: 1.71s	remaining: 5.16s
# 249:	learn: 0.1053323	total: 1.72s	remaining: 5.16s
# 250:	learn: 0.1052739	total: 1.75s	remaining: 5.21s
# 251:	learn: 0.1050298	total: 1.76s	remaining: 5.23s
# 252:	learn: 0.1049836	total: 1.79s	remaining: 5.28s
# 253:	learn: 0.1049000	total: 1.81s	remaining: 5.32s
# 254:	learn: 0.1048314	total: 1.82s	remaining: 5.33s
# 255:	learn: 0.1046750	total: 1.84s	remaining: 5.34s
# 256:	learn: 0.1045777	total: 1.86s	remaining: 5.38s
# 257:	learn: 0.1044032	total: 1.87s	remaining: 5.39s
# 258:	learn: 0.1042650	total: 1.89s	remaining: 5.4s
# 259:	learn: 0.1041241	total: 1.9s	remaining: 5.42s
# 260:	learn: 0.1039713	total: 1.93s	remaining: 5.45s
# 261:	learn: 0.1038304	total: 1.94s	remaining: 5.46s
# 262:	learn: 0.1037040	total: 1.95s	remaining: 5.46s
# 263:	learn: 0.1036673	total: 1.96s	remaining: 5.46s
# 264:	learn: 0.1036334	total: 1.96s	remaining: 5.45s
# 265:	learn: 0.1035481	total: 1.97s	remaining: 5.45s
# 266:	learn: 0.1034670	total: 1.98s	remaining: 5.44s
# 267:	learn: 0.1032951	total: 1.99s	remaining: 5.43s
# 268:	learn: 0.1031816	total: 2s	remaining: 5.42s
# 269:	learn: 0.1031407	total: 2s	remaining: 5.41s
# 270:	learn: 0.1030318	total: 2.01s	remaining: 5.4s
# 271:	learn: 0.1029169	total: 2.02s	remaining: 5.39s
# 272:	learn: 0.1028379	total: 2.02s	remaining: 5.38s
# 273:	learn: 0.1026223	total: 2.03s	remaining: 5.38s
# 274:	learn: 0.1024930	total: 2.04s	remaining: 5.37s
# 275:	learn: 0.1024241	total: 2.04s	remaining: 5.36s
# 276:	learn: 0.1023407	total: 2.05s	remaining: 5.35s
# 277:	learn: 0.1022150	total: 2.05s	remaining: 5.34s
# 278:	learn: 0.1021381	total: 2.06s	remaining: 5.33s
# 279:	learn: 0.1018805	total: 2.07s	remaining: 5.32s
# 280:	learn: 0.1017701	total: 2.07s	remaining: 5.31s
# 281:	learn: 0.1016294	total: 2.08s	remaining: 5.3s
# 282:	learn: 0.1015078	total: 2.09s	remaining: 5.29s
# 283:	learn: 0.1014340	total: 2.09s	remaining: 5.28s
# 284:	learn: 0.1013516	total: 2.1s	remaining: 5.27s
# 285:	learn: 0.1012765	total: 2.11s	remaining: 5.26s
# 286:	learn: 0.1010879	total: 2.11s	remaining: 5.25s
# 287:	learn: 0.1008654	total: 2.12s	remaining: 5.24s
# 288:	learn: 0.1007144	total: 2.13s	remaining: 5.24s
# 289:	learn: 0.1006379	total: 2.13s	remaining: 5.23s
# 290:	learn: 0.1004886	total: 2.14s	remaining: 5.22s
# 291:	learn: 0.1003845	total: 2.15s	remaining: 5.21s
# 292:	learn: 0.1002509	total: 2.16s	remaining: 5.21s
# 293:	learn: 0.1001321	total: 2.17s	remaining: 5.2s
# 294:	learn: 0.0999848	total: 2.17s	remaining: 5.19s
# 295:	learn: 0.0998244	total: 2.18s	remaining: 5.19s
# 296:	learn: 0.0997158	total: 2.19s	remaining: 5.18s
# 297:	learn: 0.0996350	total: 2.19s	remaining: 5.17s
# 298:	learn: 0.0995099	total: 2.2s	remaining: 5.16s
# 299:	learn: 0.0994401	total: 2.21s	remaining: 5.15s
# 300:	learn: 0.0993893	total: 2.21s	remaining: 5.14s
# 301:	learn: 0.0992432	total: 2.22s	remaining: 5.13s
# 302:	learn: 0.0991063	total: 2.23s	remaining: 5.12s
# 303:	learn: 0.0990791	total: 2.23s	remaining: 5.12s
# 304:	learn: 0.0990046	total: 2.24s	remaining: 5.11s
# 305:	learn: 0.0989379	total: 2.25s	remaining: 5.1s
# 306:	learn: 0.0988543	total: 2.25s	remaining: 5.09s
# 307:	learn: 0.0988171	total: 2.26s	remaining: 5.08s
# 308:	learn: 0.0987593	total: 2.27s	remaining: 5.07s
# 309:	learn: 0.0986497	total: 2.27s	remaining: 5.06s
# 310:	learn: 0.0984871	total: 2.28s	remaining: 5.05s
# 311:	learn: 0.0984204	total: 2.29s	remaining: 5.04s
# 312:	learn: 0.0983448	total: 2.29s	remaining: 5.04s
# 313:	learn: 0.0982603	total: 2.3s	remaining: 5.03s
# 314:	learn: 0.0982125	total: 2.31s	remaining: 5.02s
# 315:	learn: 0.0981239	total: 2.31s	remaining: 5.01s
# 316:	learn: 0.0980093	total: 2.32s	remaining: 5s
# 317:	learn: 0.0979722	total: 2.33s	remaining: 4.99s
# 318:	learn: 0.0979185	total: 2.34s	remaining: 4.99s
# 319:	learn: 0.0978445	total: 2.34s	remaining: 4.98s
# 320:	learn: 0.0977708	total: 2.35s	remaining: 4.97s
# 321:	learn: 0.0976944	total: 2.36s	remaining: 4.97s
# 322:	learn: 0.0975879	total: 2.37s	remaining: 4.96s
# 323:	learn: 0.0975183	total: 2.37s	remaining: 4.95s
# 324:	learn: 0.0974031	total: 2.38s	remaining: 4.95s
# 325:	learn: 0.0973336	total: 2.39s	remaining: 4.94s
# 326:	learn: 0.0972695	total: 2.4s	remaining: 4.93s
# 327:	learn: 0.0971769	total: 2.4s	remaining: 4.92s
# 328:	learn: 0.0970172	total: 2.41s	remaining: 4.92s
# 329:	learn: 0.0969036	total: 2.42s	remaining: 4.91s
# 330:	learn: 0.0968326	total: 2.42s	remaining: 4.9s
# 331:	learn: 0.0967656	total: 2.43s	remaining: 4.89s
# 332:	learn: 0.0966544	total: 2.44s	remaining: 4.88s
# 333:	learn: 0.0966130	total: 2.44s	remaining: 4.87s
# 334:	learn: 0.0965652	total: 2.45s	remaining: 4.87s
# 335:	learn: 0.0963942	total: 2.46s	remaining: 4.86s
# 336:	learn: 0.0962932	total: 2.46s	remaining: 4.85s
# 337:	learn: 0.0961746	total: 2.47s	remaining: 4.84s
# 338:	learn: 0.0960786	total: 2.48s	remaining: 4.83s
# 339:	learn: 0.0959770	total: 2.48s	remaining: 4.82s
# 340:	learn: 0.0958635	total: 2.49s	remaining: 4.81s
# 341:	learn: 0.0958217	total: 2.5s	remaining: 4.8s
# 342:	learn: 0.0957765	total: 2.5s	remaining: 4.8s
# 343:	learn: 0.0956882	total: 2.51s	remaining: 4.79s
# 344:	learn: 0.0955649	total: 2.52s	remaining: 4.78s
# 345:	learn: 0.0955490	total: 2.52s	remaining: 4.77s
# 346:	learn: 0.0955066	total: 2.53s	remaining: 4.77s
# 347:	learn: 0.0954578	total: 2.54s	remaining: 4.76s
# 348:	learn: 0.0953135	total: 2.55s	remaining: 4.75s
# 349:	learn: 0.0952670	total: 2.56s	remaining: 4.75s
# 350:	learn: 0.0952200	total: 2.56s	remaining: 4.74s
# 351:	learn: 0.0951843	total: 2.57s	remaining: 4.73s
# 352:	learn: 0.0951581	total: 2.58s	remaining: 4.73s
# 353:	learn: 0.0950649	total: 2.59s	remaining: 4.72s
# 354:	learn: 0.0949432	total: 2.59s	remaining: 4.71s
# 355:	learn: 0.0949273	total: 2.6s	remaining: 4.71s
# 356:	learn: 0.0948704	total: 2.61s	remaining: 4.7s
# 357:	learn: 0.0947571	total: 2.61s	remaining: 4.69s
# 358:	learn: 0.0946514	total: 2.62s	remaining: 4.68s
# 359:	learn: 0.0945832	total: 2.63s	remaining: 4.67s
# 360:	learn: 0.0945021	total: 2.63s	remaining: 4.66s
# 361:	learn: 0.0944406	total: 2.64s	remaining: 4.65s
# 362:	learn: 0.0943082	total: 2.65s	remaining: 4.65s
# 363:	learn: 0.0942797	total: 2.65s	remaining: 4.64s
# 364:	learn: 0.0942164	total: 2.66s	remaining: 4.63s
# 365:	learn: 0.0941038	total: 2.67s	remaining: 4.62s
# 366:	learn: 0.0939429	total: 2.67s	remaining: 4.61s
# 367:	learn: 0.0938823	total: 2.68s	remaining: 4.6s
# 368:	learn: 0.0938331	total: 2.69s	remaining: 4.59s
# 369:	learn: 0.0937844	total: 2.69s	remaining: 4.59s
# 370:	learn: 0.0936823	total: 2.7s	remaining: 4.58s
# 371:	learn: 0.0935939	total: 2.71s	remaining: 4.57s
# 372:	learn: 0.0934232	total: 2.71s	remaining: 4.56s
# 373:	learn: 0.0934076	total: 2.72s	remaining: 4.55s
# 374:	learn: 0.0933696	total: 2.73s	remaining: 4.54s
# 375:	learn: 0.0932762	total: 2.73s	remaining: 4.54s
# 376:	learn: 0.0931419	total: 2.74s	remaining: 4.53s
# 377:	learn: 0.0931038	total: 2.75s	remaining: 4.52s
# 378:	learn: 0.0929781	total: 2.76s	remaining: 4.52s
# 379:	learn: 0.0929453	total: 2.76s	remaining: 4.51s
# 380:	learn: 0.0929176	total: 2.77s	remaining: 4.5s
# 381:	learn: 0.0927858	total: 2.78s	remaining: 4.5s
# 382:	learn: 0.0927391	total: 2.79s	remaining: 4.49s
# 383:	learn: 0.0927078	total: 2.79s	remaining: 4.48s
# 384:	learn: 0.0925560	total: 2.8s	remaining: 4.48s
# 385:	learn: 0.0924004	total: 2.81s	remaining: 4.47s
# 386:	learn: 0.0923113	total: 2.81s	remaining: 4.46s
# 387:	learn: 0.0921668	total: 2.82s	remaining: 4.45s
# 388:	learn: 0.0921334	total: 2.83s	remaining: 4.44s
# 389:	learn: 0.0920332	total: 2.83s	remaining: 4.43s
# 390:	learn: 0.0919841	total: 2.84s	remaining: 4.43s
# 391:	learn: 0.0918642	total: 2.85s	remaining: 4.42s
# 392:	learn: 0.0917384	total: 2.85s	remaining: 4.41s
# 393:	learn: 0.0916788	total: 2.86s	remaining: 4.4s
# 394:	learn: 0.0916377	total: 2.87s	remaining: 4.39s
# 395:	learn: 0.0914629	total: 2.88s	remaining: 4.38s
# 396:	learn: 0.0913873	total: 2.88s	remaining: 4.38s
# 397:	learn: 0.0913488	total: 2.89s	remaining: 4.37s
# 398:	learn: 0.0912923	total: 2.9s	remaining: 4.36s
# 399:	learn: 0.0912365	total: 2.9s	remaining: 4.35s
# 400:	learn: 0.0912196	total: 2.91s	remaining: 4.34s
# 401:	learn: 0.0911928	total: 2.91s	remaining: 4.33s
# 402:	learn: 0.0911322	total: 2.92s	remaining: 4.33s
# 403:	learn: 0.0910270	total: 2.93s	remaining: 4.32s
# 404:	learn: 0.0909175	total: 2.93s	remaining: 4.31s
# 405:	learn: 0.0907816	total: 2.94s	remaining: 4.3s
# 406:	learn: 0.0906929	total: 2.95s	remaining: 4.3s
# 407:	learn: 0.0906020	total: 2.96s	remaining: 4.29s
# 408:	learn: 0.0905293	total: 2.96s	remaining: 4.29s
# 409:	learn: 0.0904317	total: 2.97s	remaining: 4.28s
# 410:	learn: 0.0902869	total: 2.98s	remaining: 4.27s
# 411:	learn: 0.0902366	total: 2.99s	remaining: 4.26s
# 412:	learn: 0.0901936	total: 3s	remaining: 4.26s
# 413:	learn: 0.0901631	total: 3s	remaining: 4.25s
# 414:	learn: 0.0901243	total: 3.01s	remaining: 4.24s
# 415:	learn: 0.0900451	total: 3.02s	remaining: 4.23s
# 416:	learn: 0.0899209	total: 3.02s	remaining: 4.22s
# 417:	learn: 0.0898025	total: 3.03s	remaining: 4.22s
# 418:	learn: 0.0897453	total: 3.04s	remaining: 4.21s
# 419:	learn: 0.0896137	total: 3.04s	remaining: 4.2s
# 420:	learn: 0.0895762	total: 3.05s	remaining: 4.19s
# 421:	learn: 0.0894943	total: 3.06s	remaining: 4.18s
# 422:	learn: 0.0893438	total: 3.06s	remaining: 4.18s
# 423:	learn: 0.0892821	total: 3.07s	remaining: 4.17s
# 424:	learn: 0.0891895	total: 3.08s	remaining: 4.16s
# 425:	learn: 0.0891412	total: 3.08s	remaining: 4.15s
# 426:	learn: 0.0891256	total: 3.09s	remaining: 4.14s
# 427:	learn: 0.0891058	total: 3.1s	remaining: 4.14s
# 428:	learn: 0.0889940	total: 3.1s	remaining: 4.13s
# 429:	learn: 0.0889353	total: 3.11s	remaining: 4.12s
# 430:	learn: 0.0888778	total: 3.12s	remaining: 4.11s
# 431:	learn: 0.0888350	total: 3.12s	remaining: 4.11s
# 432:	learn: 0.0888007	total: 3.13s	remaining: 4.1s
# 433:	learn: 0.0887294	total: 3.14s	remaining: 4.09s
# 434:	learn: 0.0886591	total: 3.14s	remaining: 4.08s
# 435:	learn: 0.0885538	total: 3.15s	remaining: 4.08s
# 436:	learn: 0.0885051	total: 3.16s	remaining: 4.07s
# 437:	learn: 0.0884586	total: 3.17s	remaining: 4.06s
# 438:	learn: 0.0884076	total: 3.17s	remaining: 4.06s
# 439:	learn: 0.0882823	total: 3.18s	remaining: 4.05s
# 440:	learn: 0.0881971	total: 3.19s	remaining: 4.04s
# 441:	learn: 0.0881267	total: 3.2s	remaining: 4.04s
# 442:	learn: 0.0880355	total: 3.2s	remaining: 4.03s
# 443:	learn: 0.0879557	total: 3.21s	remaining: 4.02s
# 444:	learn: 0.0879176	total: 3.22s	remaining: 4.01s
# 445:	learn: 0.0878708	total: 3.22s	remaining: 4s
# 446:	learn: 0.0878329	total: 3.23s	remaining: 4s
# 447:	learn: 0.0877212	total: 3.24s	remaining: 3.99s
# 448:	learn: 0.0876623	total: 3.24s	remaining: 3.98s
# 449:	learn: 0.0875926	total: 3.25s	remaining: 3.97s
# 450:	learn: 0.0875107	total: 3.26s	remaining: 3.96s
# 451:	learn: 0.0874944	total: 3.26s	remaining: 3.96s
# 452:	learn: 0.0874378	total: 3.27s	remaining: 3.95s
# 453:	learn: 0.0874021	total: 3.28s	remaining: 3.94s
# 454:	learn: 0.0873831	total: 3.28s	remaining: 3.93s
# 455:	learn: 0.0872975	total: 3.29s	remaining: 3.92s
# 456:	learn: 0.0871543	total: 3.3s	remaining: 3.92s
# 457:	learn: 0.0870555	total: 3.3s	remaining: 3.91s
# 458:	learn: 0.0870361	total: 3.31s	remaining: 3.9s
# 459:	learn: 0.0869093	total: 3.32s	remaining: 3.89s
# 460:	learn: 0.0867984	total: 3.32s	remaining: 3.89s
# 461:	learn: 0.0866309	total: 3.33s	remaining: 3.88s
# 462:	learn: 0.0865466	total: 3.34s	remaining: 3.87s
# 463:	learn: 0.0864817	total: 3.34s	remaining: 3.86s
# 464:	learn: 0.0864397	total: 3.35s	remaining: 3.85s
# 465:	learn: 0.0864036	total: 3.36s	remaining: 3.85s
# 466:	learn: 0.0862705	total: 3.37s	remaining: 3.84s
# 467:	learn: 0.0861752	total: 3.37s	remaining: 3.83s
# 468:	learn: 0.0861548	total: 3.38s	remaining: 3.83s
# 469:	learn: 0.0860174	total: 3.39s	remaining: 3.82s
# 470:	learn: 0.0859294	total: 3.4s	remaining: 3.81s
# 471:	learn: 0.0858748	total: 3.42s	remaining: 3.83s
# 472:	learn: 0.0858105	total: 3.44s	remaining: 3.83s
# 473:	learn: 0.0857420	total: 3.47s	remaining: 3.85s
# 474:	learn: 0.0856745	total: 3.48s	remaining: 3.85s
# 475:	learn: 0.0856604	total: 3.51s	remaining: 3.86s
# 476:	learn: 0.0855216	total: 3.52s	remaining: 3.86s
# 477:	learn: 0.0854520	total: 3.54s	remaining: 3.86s
# 478:	learn: 0.0853010	total: 3.55s	remaining: 3.87s
# 479:	learn: 0.0851810	total: 3.58s	remaining: 3.88s
# 480:	learn: 0.0850709	total: 3.59s	remaining: 3.87s
# 481:	learn: 0.0850362	total: 3.6s	remaining: 3.87s
# 482:	learn: 0.0850071	total: 3.6s	remaining: 3.86s
# 483:	learn: 0.0849558	total: 3.61s	remaining: 3.85s
# 484:	learn: 0.0848640	total: 3.62s	remaining: 3.85s
# 485:	learn: 0.0847038	total: 3.63s	remaining: 3.84s
# 486:	learn: 0.0846663	total: 3.64s	remaining: 3.83s
# 487:	learn: 0.0846370	total: 3.67s	remaining: 3.85s
# 488:	learn: 0.0846138	total: 3.68s	remaining: 3.85s
# 489:	learn: 0.0845053	total: 3.69s	remaining: 3.84s
# 490:	learn: 0.0844249	total: 3.7s	remaining: 3.84s
# 491:	learn: 0.0842723	total: 3.71s	remaining: 3.83s
# 492:	learn: 0.0841905	total: 3.71s	remaining: 3.82s
# 493:	learn: 0.0840237	total: 3.72s	remaining: 3.81s
# 494:	learn: 0.0840012	total: 3.73s	remaining: 3.8s
# 495:	learn: 0.0839262	total: 3.73s	remaining: 3.79s
# 496:	learn: 0.0838833	total: 3.74s	remaining: 3.79s
# 497:	learn: 0.0838084	total: 3.75s	remaining: 3.78s
# 498:	learn: 0.0837900	total: 3.75s	remaining: 3.77s
# 499:	learn: 0.0836362	total: 3.76s	remaining: 3.76s
# 500:	learn: 0.0836045	total: 3.77s	remaining: 3.75s
# 501:	learn: 0.0835217	total: 3.77s	remaining: 3.75s
# 502:	learn: 0.0834031	total: 3.78s	remaining: 3.74s
# 503:	learn: 0.0833096	total: 3.79s	remaining: 3.73s
# 504:	learn: 0.0832513	total: 3.8s	remaining: 3.72s
# 505:	learn: 0.0831341	total: 3.81s	remaining: 3.71s
# 506:	learn: 0.0830714	total: 3.81s	remaining: 3.71s
# 507:	learn: 0.0830025	total: 3.82s	remaining: 3.7s
# 508:	learn: 0.0828786	total: 3.83s	remaining: 3.69s
# 509:	learn: 0.0828336	total: 3.84s	remaining: 3.69s
# 510:	learn: 0.0827996	total: 3.84s	remaining: 3.68s
# 511:	learn: 0.0826490	total: 3.85s	remaining: 3.67s
# 512:	learn: 0.0825609	total: 3.86s	remaining: 3.66s
# 513:	learn: 0.0824899	total: 3.87s	remaining: 3.65s
# 514:	learn: 0.0824592	total: 3.87s	remaining: 3.65s
# 515:	learn: 0.0823893	total: 3.88s	remaining: 3.64s
# 516:	learn: 0.0823067	total: 3.89s	remaining: 3.63s
# 517:	learn: 0.0822684	total: 3.89s	remaining: 3.62s
# 518:	learn: 0.0822189	total: 3.9s	remaining: 3.61s
# 519:	learn: 0.0821819	total: 3.91s	remaining: 3.6s
# 520:	learn: 0.0821719	total: 3.91s	remaining: 3.6s
# 521:	learn: 0.0820442	total: 3.92s	remaining: 3.59s
# 522:	learn: 0.0820173	total: 3.92s	remaining: 3.58s
# 523:	learn: 0.0819157	total: 3.93s	remaining: 3.57s
# 524:	learn: 0.0818951	total: 3.94s	remaining: 3.56s
# 525:	learn: 0.0818320	total: 3.95s	remaining: 3.56s
# 526:	learn: 0.0817859	total: 3.95s	remaining: 3.55s
# 527:	learn: 0.0817656	total: 3.96s	remaining: 3.54s
# 528:	learn: 0.0817333	total: 3.96s	remaining: 3.53s
# 529:	learn: 0.0817062	total: 3.97s	remaining: 3.52s
# 530:	learn: 0.0815634	total: 3.98s	remaining: 3.51s
# 531:	learn: 0.0815045	total: 3.99s	remaining: 3.51s
# 532:	learn: 0.0814398	total: 3.99s	remaining: 3.5s
# 533:	learn: 0.0814118	total: 4s	remaining: 3.49s
# 534:	learn: 0.0813826	total: 4.01s	remaining: 3.48s
# 535:	learn: 0.0813195	total: 4.02s	remaining: 3.48s
# 536:	learn: 0.0812016	total: 4.02s	remaining: 3.47s
# 537:	learn: 0.0811875	total: 4.03s	remaining: 3.46s
# 538:	learn: 0.0811408	total: 4.04s	remaining: 3.46s
# 539:	learn: 0.0810459	total: 4.05s	remaining: 3.45s
# 540:	learn: 0.0809654	total: 4.05s	remaining: 3.44s
# 541:	learn: 0.0808686	total: 4.06s	remaining: 3.43s
# 542:	learn: 0.0807300	total: 4.07s	remaining: 3.42s
# 543:	learn: 0.0806282	total: 4.08s	remaining: 3.42s
# 544:	learn: 0.0805341	total: 4.08s	remaining: 3.41s
# 545:	learn: 0.0804637	total: 4.09s	remaining: 3.4s
# 546:	learn: 0.0803646	total: 4.1s	remaining: 3.39s
# 547:	learn: 0.0803025	total: 4.1s	remaining: 3.38s
# 548:	learn: 0.0802082	total: 4.11s	remaining: 3.38s
# 549:	learn: 0.0801056	total: 4.12s	remaining: 3.37s
# 550:	learn: 0.0800229	total: 4.12s	remaining: 3.36s
# 551:	learn: 0.0800051	total: 4.13s	remaining: 3.35s
# 552:	learn: 0.0798924	total: 4.14s	remaining: 3.34s
# 553:	learn: 0.0798138	total: 4.14s	remaining: 3.33s
# 554:	learn: 0.0797910	total: 4.15s	remaining: 3.33s
# 555:	learn: 0.0796761	total: 4.16s	remaining: 3.32s
# 556:	learn: 0.0795419	total: 4.16s	remaining: 3.31s
# 557:	learn: 0.0794971	total: 4.17s	remaining: 3.3s
# 558:	learn: 0.0793972	total: 4.18s	remaining: 3.29s
# 559:	learn: 0.0793141	total: 4.18s	remaining: 3.29s
# 560:	learn: 0.0792054	total: 4.19s	remaining: 3.28s
# 561:	learn: 0.0791106	total: 4.2s	remaining: 3.27s
# 562:	learn: 0.0790364	total: 4.2s	remaining: 3.26s
# 563:	learn: 0.0790182	total: 4.21s	remaining: 3.25s
# 564:	learn: 0.0789929	total: 4.22s	remaining: 3.25s
# 565:	learn: 0.0788129	total: 4.23s	remaining: 3.24s
# 566:	learn: 0.0787041	total: 4.23s	remaining: 3.23s
# 567:	learn: 0.0786263	total: 4.24s	remaining: 3.23s
# 568:	learn: 0.0785783	total: 4.25s	remaining: 3.22s
# 569:	learn: 0.0784904	total: 4.26s	remaining: 3.21s
# 570:	learn: 0.0784055	total: 4.26s	remaining: 3.2s
# 571:	learn: 0.0783189	total: 4.27s	remaining: 3.2s
# 572:	learn: 0.0782943	total: 4.28s	remaining: 3.19s
# 573:	learn: 0.0782021	total: 4.29s	remaining: 3.18s
# 574:	learn: 0.0781684	total: 4.29s	remaining: 3.17s
# 575:	learn: 0.0780821	total: 4.3s	remaining: 3.16s
# 576:	learn: 0.0780530	total: 4.31s	remaining: 3.16s
# 577:	learn: 0.0779659	total: 4.31s	remaining: 3.15s
# 578:	learn: 0.0778429	total: 4.32s	remaining: 3.14s
# 579:	learn: 0.0777850	total: 4.33s	remaining: 3.13s
# 580:	learn: 0.0777614	total: 4.33s	remaining: 3.12s
# 581:	learn: 0.0777375	total: 4.34s	remaining: 3.12s
# 582:	learn: 0.0777074	total: 4.34s	remaining: 3.11s
# 583:	learn: 0.0776833	total: 4.35s	remaining: 3.1s
# 584:	learn: 0.0776262	total: 4.36s	remaining: 3.09s
# 585:	learn: 0.0775486	total: 4.37s	remaining: 3.08s
# 586:	learn: 0.0774627	total: 4.37s	remaining: 3.08s
# 587:	learn: 0.0774474	total: 4.38s	remaining: 3.07s
# 588:	learn: 0.0773877	total: 4.39s	remaining: 3.06s
# 589:	learn: 0.0772982	total: 4.39s	remaining: 3.05s
# 590:	learn: 0.0772329	total: 4.4s	remaining: 3.05s
# 591:	learn: 0.0771156	total: 4.41s	remaining: 3.04s
# 592:	learn: 0.0769871	total: 4.42s	remaining: 3.03s
# 593:	learn: 0.0769069	total: 4.42s	remaining: 3.02s
# 594:	learn: 0.0768820	total: 4.43s	remaining: 3.02s
# 595:	learn: 0.0767426	total: 4.44s	remaining: 3.01s
# 596:	learn: 0.0767034	total: 4.45s	remaining: 3s
# 597:	learn: 0.0766708	total: 4.46s	remaining: 3s
# 598:	learn: 0.0766347	total: 4.46s	remaining: 2.99s
# 599:	learn: 0.0765645	total: 4.47s	remaining: 2.98s
# 600:	learn: 0.0764580	total: 4.48s	remaining: 2.97s
# 601:	learn: 0.0764417	total: 4.48s	remaining: 2.96s
# 602:	learn: 0.0763791	total: 4.49s	remaining: 2.96s
# 603:	learn: 0.0762692	total: 4.5s	remaining: 2.95s
# 604:	learn: 0.0761850	total: 4.5s	remaining: 2.94s
# 605:	learn: 0.0761683	total: 4.51s	remaining: 2.93s
# 606:	learn: 0.0760707	total: 4.52s	remaining: 2.92s
# 607:	learn: 0.0760166	total: 4.52s	remaining: 2.92s
# 608:	learn: 0.0759481	total: 4.53s	remaining: 2.91s
# 609:	learn: 0.0758310	total: 4.54s	remaining: 2.9s
# 610:	learn: 0.0758193	total: 4.54s	remaining: 2.89s
# 611:	learn: 0.0757513	total: 4.55s	remaining: 2.88s
# 612:	learn: 0.0756866	total: 4.56s	remaining: 2.88s
# 613:	learn: 0.0755712	total: 4.56s	remaining: 2.87s
# 614:	learn: 0.0754780	total: 4.57s	remaining: 2.86s
# 615:	learn: 0.0753643	total: 4.58s	remaining: 2.85s
# 616:	learn: 0.0752811	total: 4.58s	remaining: 2.84s
# 617:	learn: 0.0752649	total: 4.59s	remaining: 2.84s
# 618:	learn: 0.0751572	total: 4.6s	remaining: 2.83s
# 619:	learn: 0.0750192	total: 4.6s	remaining: 2.82s
# 620:	learn: 0.0749263	total: 4.61s	remaining: 2.81s
# 621:	learn: 0.0748150	total: 4.62s	remaining: 2.81s
# 622:	learn: 0.0747962	total: 4.63s	remaining: 2.8s
# 623:	learn: 0.0747858	total: 4.63s	remaining: 2.79s
# 624:	learn: 0.0747470	total: 4.64s	remaining: 2.78s
# 625:	learn: 0.0746244	total: 4.65s	remaining: 2.78s
# 626:	learn: 0.0745579	total: 4.66s	remaining: 2.77s
# 627:	learn: 0.0744786	total: 4.66s	remaining: 2.76s
# 628:	learn: 0.0743968	total: 4.67s	remaining: 2.76s
# 629:	learn: 0.0742997	total: 4.68s	remaining: 2.75s
# 630:	learn: 0.0742205	total: 4.69s	remaining: 2.74s
# 631:	learn: 0.0742048	total: 4.7s	remaining: 2.73s
# 632:	learn: 0.0741163	total: 4.7s	remaining: 2.73s
# 633:	learn: 0.0740218	total: 4.71s	remaining: 2.72s
# 634:	learn: 0.0739195	total: 4.71s	remaining: 2.71s
# 635:	learn: 0.0739061	total: 4.72s	remaining: 2.7s
# 636:	learn: 0.0738666	total: 4.73s	remaining: 2.69s
# 637:	learn: 0.0738392	total: 4.73s	remaining: 2.69s
# 638:	learn: 0.0737529	total: 4.74s	remaining: 2.68s
# 639:	learn: 0.0736711	total: 4.75s	remaining: 2.67s
# 640:	learn: 0.0735575	total: 4.75s	remaining: 2.66s
# 641:	learn: 0.0735472	total: 4.76s	remaining: 2.65s
# 642:	learn: 0.0735228	total: 4.77s	remaining: 2.65s
# 643:	learn: 0.0734073	total: 4.77s	remaining: 2.64s
# 644:	learn: 0.0733358	total: 4.78s	remaining: 2.63s
# 645:	learn: 0.0732603	total: 4.79s	remaining: 2.62s
# 646:	learn: 0.0732422	total: 4.79s	remaining: 2.62s
# 647:	learn: 0.0731521	total: 4.8s	remaining: 2.61s
# 648:	learn: 0.0730747	total: 4.81s	remaining: 2.6s
# 649:	learn: 0.0729847	total: 4.81s	remaining: 2.59s
# 650:	learn: 0.0729482	total: 4.82s	remaining: 2.58s
# 651:	learn: 0.0728530	total: 4.83s	remaining: 2.58s
# 652:	learn: 0.0727841	total: 4.83s	remaining: 2.57s
# 653:	learn: 0.0727045	total: 4.84s	remaining: 2.56s
# 654:	learn: 0.0726495	total: 4.85s	remaining: 2.55s
# 655:	learn: 0.0726021	total: 4.86s	remaining: 2.55s
# 656:	learn: 0.0725175	total: 4.86s	remaining: 2.54s
# 657:	learn: 0.0724385	total: 4.87s	remaining: 2.53s
# 658:	learn: 0.0723560	total: 4.88s	remaining: 2.52s
# 659:	learn: 0.0723438	total: 4.89s	remaining: 2.52s
# 660:	learn: 0.0722048	total: 4.89s	remaining: 2.51s
# 661:	learn: 0.0721104	total: 4.9s	remaining: 2.5s
# 662:	learn: 0.0720513	total: 4.91s	remaining: 2.49s
# 663:	learn: 0.0720204	total: 4.91s	remaining: 2.49s
# 664:	learn: 0.0718897	total: 4.92s	remaining: 2.48s
# 665:	learn: 0.0717974	total: 4.93s	remaining: 2.47s
# 666:	learn: 0.0717766	total: 4.93s	remaining: 2.46s
# 667:	learn: 0.0717000	total: 4.94s	remaining: 2.45s
# 668:	learn: 0.0715603	total: 4.95s	remaining: 2.45s
# 669:	learn: 0.0714889	total: 4.95s	remaining: 2.44s
# 670:	learn: 0.0714064	total: 4.96s	remaining: 2.43s
# 671:	learn: 0.0713491	total: 4.96s	remaining: 2.42s
# 672:	learn: 0.0712227	total: 4.97s	remaining: 2.42s
# 673:	learn: 0.0712011	total: 4.98s	remaining: 2.41s
# 674:	learn: 0.0711228	total: 4.98s	remaining: 2.4s
# 675:	learn: 0.0711054	total: 4.99s	remaining: 2.39s
# 676:	learn: 0.0710940	total: 5s	remaining: 2.38s
# 677:	learn: 0.0709891	total: 5s	remaining: 2.38s
# 678:	learn: 0.0709224	total: 5.01s	remaining: 2.37s
# 679:	learn: 0.0708098	total: 5.02s	remaining: 2.36s
# 680:	learn: 0.0707073	total: 5.02s	remaining: 2.35s
# 681:	learn: 0.0706539	total: 5.03s	remaining: 2.35s
# 682:	learn: 0.0706305	total: 5.04s	remaining: 2.34s
# 683:	learn: 0.0705936	total: 5.05s	remaining: 2.33s
# 684:	learn: 0.0704939	total: 5.06s	remaining: 2.33s
# 685:	learn: 0.0703719	total: 5.07s	remaining: 2.32s
# 686:	learn: 0.0702468	total: 5.08s	remaining: 2.32s
# 687:	learn: 0.0701570	total: 5.1s	remaining: 2.31s
# 688:	learn: 0.0700603	total: 5.11s	remaining: 2.3s
# 689:	learn: 0.0699659	total: 5.11s	remaining: 2.3s
# 690:	learn: 0.0698775	total: 5.12s	remaining: 2.29s
# 691:	learn: 0.0697808	total: 5.12s	remaining: 2.28s
# 692:	learn: 0.0697273	total: 5.13s	remaining: 2.27s
# 693:	learn: 0.0696730	total: 5.14s	remaining: 2.27s
# 694:	learn: 0.0696486	total: 5.14s	remaining: 2.26s
# 695:	learn: 0.0695288	total: 5.15s	remaining: 2.25s
# 696:	learn: 0.0693924	total: 5.16s	remaining: 2.24s
# 697:	learn: 0.0693073	total: 5.17s	remaining: 2.23s
# 698:	learn: 0.0692918	total: 5.17s	remaining: 2.23s
# 699:	learn: 0.0692824	total: 5.18s	remaining: 2.22s
# 700:	learn: 0.0691260	total: 5.18s	remaining: 2.21s
# 701:	learn: 0.0691103	total: 5.19s	remaining: 2.2s
# 702:	learn: 0.0690197	total: 5.2s	remaining: 2.19s
# 703:	learn: 0.0689419	total: 5.2s	remaining: 2.19s
# 704:	learn: 0.0688665	total: 5.21s	remaining: 2.18s
# 705:	learn: 0.0688194	total: 5.22s	remaining: 2.17s
# 706:	learn: 0.0687067	total: 5.22s	remaining: 2.16s
# 707:	learn: 0.0685952	total: 5.23s	remaining: 2.16s
# 708:	learn: 0.0685414	total: 5.24s	remaining: 2.15s
# 709:	learn: 0.0684990	total: 5.25s	remaining: 2.14s
# 710:	learn: 0.0684206	total: 5.25s	remaining: 2.14s
# 711:	learn: 0.0683561	total: 5.26s	remaining: 2.13s
# 712:	learn: 0.0682702	total: 5.27s	remaining: 2.12s
# 713:	learn: 0.0681603	total: 5.28s	remaining: 2.11s
# 714:	learn: 0.0681012	total: 5.28s	remaining: 2.11s
# 715:	learn: 0.0680457	total: 5.29s	remaining: 2.1s
# 716:	learn: 0.0679147	total: 5.3s	remaining: 2.09s
# 717:	learn: 0.0678737	total: 5.31s	remaining: 2.08s
# 718:	learn: 0.0678594	total: 5.31s	remaining: 2.08s
# 719:	learn: 0.0677719	total: 5.32s	remaining: 2.07s
# 720:	learn: 0.0677164	total: 5.33s	remaining: 2.06s
# 721:	learn: 0.0676275	total: 5.33s	remaining: 2.05s
# 722:	learn: 0.0675673	total: 5.34s	remaining: 2.05s
# 723:	learn: 0.0674900	total: 5.35s	remaining: 2.04s
# 724:	learn: 0.0674767	total: 5.35s	remaining: 2.03s
# 725:	learn: 0.0674472	total: 5.36s	remaining: 2.02s
# 726:	learn: 0.0674334	total: 5.37s	remaining: 2.02s
# 727:	learn: 0.0673548	total: 5.37s	remaining: 2.01s
# 728:	learn: 0.0672750	total: 5.38s	remaining: 2s
# 729:	learn: 0.0671655	total: 5.39s	remaining: 1.99s
# 730:	learn: 0.0670900	total: 5.39s	remaining: 1.98s
# 731:	learn: 0.0670002	total: 5.4s	remaining: 1.98s
# 732:	learn: 0.0669258	total: 5.41s	remaining: 1.97s
# 733:	learn: 0.0668346	total: 5.41s	remaining: 1.96s
# 734:	learn: 0.0667485	total: 5.42s	remaining: 1.95s
# 735:	learn: 0.0666694	total: 5.43s	remaining: 1.95s
# 736:	learn: 0.0665939	total: 5.43s	remaining: 1.94s
# 737:	learn: 0.0665124	total: 5.44s	remaining: 1.93s
# 738:	learn: 0.0664534	total: 5.45s	remaining: 1.92s
# 739:	learn: 0.0664007	total: 5.45s	remaining: 1.92s
# 740:	learn: 0.0663185	total: 5.46s	remaining: 1.91s
# 741:	learn: 0.0662786	total: 5.47s	remaining: 1.9s
# 742:	learn: 0.0662126	total: 5.48s	remaining: 1.89s
# 743:	learn: 0.0661366	total: 5.48s	remaining: 1.89s
# 744:	learn: 0.0660248	total: 5.49s	remaining: 1.88s
# 745:	learn: 0.0659715	total: 5.5s	remaining: 1.87s
# 746:	learn: 0.0658606	total: 5.5s	remaining: 1.86s
# 747:	learn: 0.0657814	total: 5.52s	remaining: 1.86s
# 748:	learn: 0.0656525	total: 5.53s	remaining: 1.85s
# 749:	learn: 0.0655782	total: 5.53s	remaining: 1.84s
# 750:	learn: 0.0654990	total: 5.54s	remaining: 1.84s
# 751:	learn: 0.0654363	total: 5.54s	remaining: 1.83s
# 752:	learn: 0.0653336	total: 5.55s	remaining: 1.82s
# 753:	learn: 0.0651974	total: 5.56s	remaining: 1.81s
# 754:	learn: 0.0651669	total: 5.56s	remaining: 1.8s
# 755:	learn: 0.0651433	total: 5.57s	remaining: 1.8s
# 756:	learn: 0.0650511	total: 5.58s	remaining: 1.79s
# 757:	learn: 0.0649670	total: 5.58s	remaining: 1.78s
# 758:	learn: 0.0649450	total: 5.59s	remaining: 1.77s
# 759:	learn: 0.0648732	total: 5.6s	remaining: 1.77s
# 760:	learn: 0.0647839	total: 5.6s	remaining: 1.76s
# 761:	learn: 0.0647152	total: 5.61s	remaining: 1.75s
# 762:	learn: 0.0646041	total: 5.62s	remaining: 1.74s
# 763:	learn: 0.0645319	total: 5.62s	remaining: 1.74s
# 764:	learn: 0.0644323	total: 5.63s	remaining: 1.73s
# 765:	learn: 0.0644151	total: 5.64s	remaining: 1.72s
# 766:	learn: 0.0643321	total: 5.64s	remaining: 1.71s
# 767:	learn: 0.0642912	total: 5.65s	remaining: 1.71s
# 768:	learn: 0.0642569	total: 5.66s	remaining: 1.7s
# 769:	learn: 0.0642206	total: 5.67s	remaining: 1.69s
# 770:	learn: 0.0641451	total: 5.67s	remaining: 1.69s
# 771:	learn: 0.0640747	total: 5.68s	remaining: 1.68s
# 772:	learn: 0.0639780	total: 5.69s	remaining: 1.67s
# 773:	learn: 0.0638899	total: 5.7s	remaining: 1.66s
# 774:	learn: 0.0637815	total: 5.7s	remaining: 1.66s
# 775:	learn: 0.0637054	total: 5.71s	remaining: 1.65s
# 776:	learn: 0.0636000	total: 5.72s	remaining: 1.64s
# 777:	learn: 0.0634826	total: 5.73s	remaining: 1.63s
# 778:	learn: 0.0634338	total: 5.73s	remaining: 1.63s
# 779:	learn: 0.0633660	total: 5.74s	remaining: 1.62s
# 780:	learn: 0.0633515	total: 5.75s	remaining: 1.61s
# 781:	learn: 0.0632411	total: 5.75s	remaining: 1.6s
# 782:	learn: 0.0631834	total: 5.76s	remaining: 1.6s
# 783:	learn: 0.0631141	total: 5.77s	remaining: 1.59s
# 784:	learn: 0.0631045	total: 5.77s	remaining: 1.58s
# 785:	learn: 0.0630643	total: 5.78s	remaining: 1.57s
# 786:	learn: 0.0629924	total: 5.79s	remaining: 1.57s
# 787:	learn: 0.0629324	total: 5.79s	remaining: 1.56s
# 788:	learn: 0.0628589	total: 5.8s	remaining: 1.55s
# 789:	learn: 0.0627900	total: 5.81s	remaining: 1.54s
# 790:	learn: 0.0627223	total: 5.81s	remaining: 1.53s
# 791:	learn: 0.0626305	total: 5.82s	remaining: 1.53s
# 792:	learn: 0.0625784	total: 5.83s	remaining: 1.52s
# 793:	learn: 0.0625037	total: 5.83s	remaining: 1.51s
# 794:	learn: 0.0624387	total: 5.84s	remaining: 1.5s
# 795:	learn: 0.0624283	total: 5.84s	remaining: 1.5s
# 796:	learn: 0.0623676	total: 5.85s	remaining: 1.49s
# 797:	learn: 0.0623624	total: 5.86s	remaining: 1.48s
# 798:	learn: 0.0622583	total: 5.87s	remaining: 1.48s
# 799:	learn: 0.0622010	total: 5.87s	remaining: 1.47s
# 800:	learn: 0.0621206	total: 5.88s	remaining: 1.46s
# 801:	learn: 0.0620491	total: 5.89s	remaining: 1.45s
# 802:	learn: 0.0619840	total: 5.9s	remaining: 1.45s
# 803:	learn: 0.0619666	total: 5.9s	remaining: 1.44s
# 804:	learn: 0.0619161	total: 5.91s	remaining: 1.43s
# 805:	learn: 0.0618123	total: 5.92s	remaining: 1.42s
# 806:	learn: 0.0617433	total: 5.93s	remaining: 1.42s
# 807:	learn: 0.0616354	total: 5.93s	remaining: 1.41s
# 808:	learn: 0.0616000	total: 5.94s	remaining: 1.4s
# 809:	learn: 0.0614903	total: 5.95s	remaining: 1.4s
# 810:	learn: 0.0614714	total: 5.95s	remaining: 1.39s
# 811:	learn: 0.0614121	total: 5.96s	remaining: 1.38s
# 812:	learn: 0.0613420	total: 5.97s	remaining: 1.37s
# 813:	learn: 0.0612732	total: 5.97s	remaining: 1.36s
# 814:	learn: 0.0612536	total: 5.98s	remaining: 1.36s
# 815:	learn: 0.0612418	total: 5.99s	remaining: 1.35s
# 816:	learn: 0.0612228	total: 5.99s	remaining: 1.34s
# 817:	learn: 0.0611876	total: 6s	remaining: 1.33s
# 818:	learn: 0.0611635	total: 6s	remaining: 1.33s
# 819:	learn: 0.0611025	total: 6.01s	remaining: 1.32s
# 820:	learn: 0.0610357	total: 6.02s	remaining: 1.31s
# 821:	learn: 0.0610297	total: 6.02s	remaining: 1.3s
# 822:	learn: 0.0609413	total: 6.03s	remaining: 1.3s
# 823:	learn: 0.0608759	total: 6.04s	remaining: 1.29s
# 824:	learn: 0.0607968	total: 6.04s	remaining: 1.28s
# 825:	learn: 0.0607440	total: 6.05s	remaining: 1.27s
# 826:	learn: 0.0607142	total: 6.06s	remaining: 1.27s
# 827:	learn: 0.0606635	total: 6.06s	remaining: 1.26s
# 828:	learn: 0.0605851	total: 6.07s	remaining: 1.25s
# 829:	learn: 0.0605521	total: 6.08s	remaining: 1.25s
# 830:	learn: 0.0605086	total: 6.09s	remaining: 1.24s
# 831:	learn: 0.0604477	total: 6.09s	remaining: 1.23s
# 832:	learn: 0.0604121	total: 6.1s	remaining: 1.22s
# 833:	learn: 0.0603354	total: 6.11s	remaining: 1.22s
# 834:	learn: 0.0602769	total: 6.12s	remaining: 1.21s
# 835:	learn: 0.0602077	total: 6.12s	remaining: 1.2s
# 836:	learn: 0.0601741	total: 6.13s	remaining: 1.19s
# 837:	learn: 0.0601547	total: 6.14s	remaining: 1.19s
# 838:	learn: 0.0600523	total: 6.14s	remaining: 1.18s
# 839:	learn: 0.0599429	total: 6.15s	remaining: 1.17s
# 840:	learn: 0.0598445	total: 6.16s	remaining: 1.16s
# 841:	learn: 0.0597882	total: 6.17s	remaining: 1.16s
# 842:	learn: 0.0596838	total: 6.17s	remaining: 1.15s
# 843:	learn: 0.0596706	total: 6.18s	remaining: 1.14s
# 844:	learn: 0.0596145	total: 6.18s	remaining: 1.13s
# 845:	learn: 0.0595714	total: 6.19s	remaining: 1.13s
# 846:	learn: 0.0594870	total: 6.2s	remaining: 1.12s
# 847:	learn: 0.0594600	total: 6.21s	remaining: 1.11s
# 848:	learn: 0.0593530	total: 6.21s	remaining: 1.1s
# 849:	learn: 0.0592881	total: 6.22s	remaining: 1.1s
# 850:	learn: 0.0592430	total: 6.23s	remaining: 1.09s
# 851:	learn: 0.0591805	total: 6.23s	remaining: 1.08s
# 852:	learn: 0.0590862	total: 6.24s	remaining: 1.07s
# 853:	learn: 0.0590804	total: 6.25s	remaining: 1.07s
# 854:	learn: 0.0590091	total: 6.25s	remaining: 1.06s
# 855:	learn: 0.0589584	total: 6.26s	remaining: 1.05s
# 856:	learn: 0.0589029	total: 6.27s	remaining: 1.04s
# 857:	learn: 0.0588370	total: 6.27s	remaining: 1.04s
# 858:	learn: 0.0588217	total: 6.28s	remaining: 1.03s
# 859:	learn: 0.0587555	total: 6.29s	remaining: 1.02s
# 860:	learn: 0.0586880	total: 6.3s	remaining: 1.02s
# 861:	learn: 0.0586027	total: 6.3s	remaining: 1.01s
# 862:	learn: 0.0585326	total: 6.31s	remaining: 1s
# 863:	learn: 0.0584979	total: 6.32s	remaining: 995ms
# 864:	learn: 0.0583930	total: 6.33s	remaining: 987ms
# 865:	learn: 0.0583608	total: 6.33s	remaining: 980ms
# 866:	learn: 0.0583009	total: 6.34s	remaining: 973ms
# 867:	learn: 0.0582561	total: 6.35s	remaining: 965ms
# 868:	learn: 0.0581818	total: 6.36s	remaining: 958ms
# 869:	learn: 0.0581640	total: 6.36s	remaining: 951ms
# 870:	learn: 0.0581476	total: 6.37s	remaining: 943ms
# 871:	learn: 0.0581402	total: 6.38s	remaining: 936ms
# 872:	learn: 0.0581067	total: 6.38s	remaining: 928ms
# 873:	learn: 0.0580317	total: 6.39s	remaining: 921ms
# 874:	learn: 0.0580148	total: 6.39s	remaining: 913ms
# 875:	learn: 0.0579388	total: 6.4s	remaining: 906ms
# 876:	learn: 0.0578425	total: 6.41s	remaining: 899ms
# 877:	learn: 0.0577898	total: 6.41s	remaining: 891ms
# 878:	learn: 0.0577592	total: 6.42s	remaining: 884ms
# 879:	learn: 0.0576734	total: 6.43s	remaining: 876ms
# 880:	learn: 0.0576198	total: 6.43s	remaining: 869ms
# 881:	learn: 0.0575661	total: 6.44s	remaining: 862ms
# 882:	learn: 0.0575071	total: 6.45s	remaining: 854ms
# 883:	learn: 0.0574525	total: 6.45s	remaining: 847ms
# 884:	learn: 0.0574199	total: 6.46s	remaining: 839ms
# 885:	learn: 0.0573954	total: 6.47s	remaining: 832ms
# 886:	learn: 0.0573458	total: 6.47s	remaining: 825ms
# 887:	learn: 0.0572881	total: 6.48s	remaining: 817ms
# 888:	learn: 0.0571566	total: 6.49s	remaining: 810ms
# 889:	learn: 0.0570929	total: 6.5s	remaining: 803ms
# 890:	learn: 0.0569944	total: 6.5s	remaining: 796ms
# 891:	learn: 0.0569357	total: 6.51s	remaining: 788ms
# 892:	learn: 0.0568804	total: 6.53s	remaining: 782ms
# 893:	learn: 0.0568250	total: 6.54s	remaining: 776ms
# 894:	learn: 0.0567951	total: 6.56s	remaining: 770ms
# 895:	learn: 0.0567491	total: 6.59s	remaining: 765ms
# 896:	learn: 0.0566454	total: 6.61s	remaining: 759ms
# 897:	learn: 0.0566190	total: 6.63s	remaining: 753ms
# 898:	learn: 0.0565633	total: 6.64s	remaining: 746ms
# 899:	learn: 0.0565356	total: 6.66s	remaining: 741ms
# 900:	learn: 0.0564307	total: 6.68s	remaining: 734ms
# 901:	learn: 0.0564041	total: 6.7s	remaining: 727ms
# 902:	learn: 0.0563365	total: 6.71s	remaining: 721ms
# 903:	learn: 0.0563110	total: 6.72s	remaining: 714ms
# 904:	learn: 0.0562882	total: 6.73s	remaining: 706ms
# 905:	learn: 0.0561920	total: 6.74s	remaining: 699ms
# 906:	learn: 0.0560920	total: 6.75s	remaining: 692ms
# 907:	learn: 0.0560410	total: 6.75s	remaining: 684ms
# 908:	learn: 0.0559734	total: 6.76s	remaining: 677ms
# 909:	learn: 0.0558962	total: 6.77s	remaining: 670ms
# 910:	learn: 0.0558628	total: 6.78s	remaining: 662ms
# 911:	learn: 0.0557873	total: 6.81s	remaining: 657ms
# 912:	learn: 0.0557342	total: 6.82s	remaining: 650ms
# 913:	learn: 0.0556185	total: 6.83s	remaining: 642ms
# 914:	learn: 0.0555315	total: 6.83s	remaining: 635ms
# 915:	learn: 0.0554687	total: 6.84s	remaining: 628ms
# 916:	learn: 0.0553935	total: 6.85s	remaining: 620ms
# 917:	learn: 0.0553340	total: 6.86s	remaining: 613ms
# 918:	learn: 0.0552700	total: 6.87s	remaining: 605ms
# 919:	learn: 0.0552257	total: 6.87s	remaining: 598ms
# 920:	learn: 0.0551572	total: 6.88s	remaining: 590ms
# 921:	learn: 0.0550595	total: 6.88s	remaining: 583ms
# 922:	learn: 0.0549381	total: 6.89s	remaining: 575ms
# 923:	learn: 0.0548820	total: 6.9s	remaining: 568ms
# 924:	learn: 0.0548311	total: 6.91s	remaining: 560ms
# 925:	learn: 0.0548147	total: 6.92s	remaining: 553ms
# 926:	learn: 0.0547679	total: 6.92s	remaining: 545ms
# 927:	learn: 0.0547503	total: 6.93s	remaining: 538ms
# 928:	learn: 0.0546974	total: 6.94s	remaining: 530ms
# 929:	learn: 0.0546445	total: 6.95s	remaining: 523ms
# 930:	learn: 0.0545814	total: 6.95s	remaining: 515ms
# 931:	learn: 0.0545097	total: 6.96s	remaining: 508ms
# 932:	learn: 0.0544755	total: 6.97s	remaining: 501ms
# 933:	learn: 0.0544337	total: 6.98s	remaining: 493ms
# 934:	learn: 0.0543675	total: 6.99s	remaining: 486ms
# 935:	learn: 0.0542873	total: 6.99s	remaining: 478ms
# 936:	learn: 0.0542378	total: 7s	remaining: 471ms
# 937:	learn: 0.0542200	total: 7s	remaining: 463ms
# 938:	learn: 0.0541724	total: 7.01s	remaining: 456ms
# 939:	learn: 0.0540915	total: 7.02s	remaining: 448ms
# 940:	learn: 0.0540759	total: 7.03s	remaining: 441ms
# 941:	learn: 0.0540192	total: 7.03s	remaining: 433ms
# 942:	learn: 0.0539611	total: 7.04s	remaining: 426ms
# 943:	learn: 0.0539122	total: 7.05s	remaining: 418ms
# 944:	learn: 0.0538883	total: 7.05s	remaining: 410ms
# 945:	learn: 0.0538086	total: 7.06s	remaining: 403ms
# 946:	learn: 0.0537698	total: 7.07s	remaining: 395ms
# 947:	learn: 0.0536864	total: 7.07s	remaining: 388ms
# 948:	learn: 0.0536346	total: 7.08s	remaining: 381ms
# 949:	learn: 0.0535849	total: 7.09s	remaining: 373ms
# 950:	learn: 0.0535679	total: 7.1s	remaining: 366ms
# 951:	learn: 0.0535080	total: 7.11s	remaining: 358ms
# 952:	learn: 0.0534554	total: 7.11s	remaining: 351ms
# 953:	learn: 0.0533644	total: 7.12s	remaining: 343ms
# 954:	learn: 0.0533104	total: 7.13s	remaining: 336ms
# 955:	learn: 0.0532605	total: 7.14s	remaining: 328ms
# 956:	learn: 0.0532065	total: 7.14s	remaining: 321ms
# 957:	learn: 0.0531254	total: 7.15s	remaining: 314ms
# 958:	learn: 0.0530560	total: 7.16s	remaining: 306ms
# 959:	learn: 0.0529629	total: 7.17s	remaining: 299ms
# 960:	learn: 0.0528625	total: 7.17s	remaining: 291ms
# 961:	learn: 0.0528023	total: 7.18s	remaining: 284ms
# 962:	learn: 0.0527491	total: 7.19s	remaining: 276ms
# 963:	learn: 0.0527197	total: 7.2s	remaining: 269ms
# 964:	learn: 0.0527150	total: 7.2s	remaining: 261ms
# 965:	learn: 0.0527103	total: 7.21s	remaining: 254ms
# 966:	learn: 0.0526548	total: 7.22s	remaining: 246ms
# 967:	learn: 0.0526161	total: 7.22s	remaining: 239ms
# 968:	learn: 0.0526017	total: 7.23s	remaining: 231ms
# 969:	learn: 0.0525945	total: 7.24s	remaining: 224ms
# 970:	learn: 0.0525445	total: 7.24s	remaining: 216ms
# 971:	learn: 0.0525287	total: 7.25s	remaining: 209ms
# 972:	learn: 0.0525132	total: 7.26s	remaining: 201ms
# 973:	learn: 0.0524362	total: 7.26s	remaining: 194ms
# 974:	learn: 0.0523882	total: 7.27s	remaining: 186ms
# 975:	learn: 0.0523241	total: 7.28s	remaining: 179ms
# 976:	learn: 0.0522754	total: 7.29s	remaining: 172ms
# 977:	learn: 0.0521983	total: 7.29s	remaining: 164ms
# 978:	learn: 0.0521202	total: 7.3s	remaining: 157ms
# 979:	learn: 0.0520293	total: 7.31s	remaining: 149ms
# 980:	learn: 0.0519661	total: 7.32s	remaining: 142ms
# 981:	learn: 0.0519071	total: 7.32s	remaining: 134ms
# 982:	learn: 0.0518981	total: 7.33s	remaining: 127ms
# 983:	learn: 0.0518318	total: 7.34s	remaining: 119ms
# 984:	learn: 0.0517930	total: 7.34s	remaining: 112ms
# 985:	learn: 0.0517165	total: 7.35s	remaining: 104ms
# 986:	learn: 0.0516225	total: 7.36s	remaining: 96.9ms
# 987:	learn: 0.0515759	total: 7.37s	remaining: 89.5ms
# 988:	learn: 0.0515514	total: 7.38s	remaining: 82ms
# 989:	learn: 0.0514911	total: 7.38s	remaining: 74.6ms
# 990:	learn: 0.0514322	total: 7.39s	remaining: 67.1ms
# 991:	learn: 0.0514111	total: 7.4s	remaining: 59.7ms
# 992:	learn: 0.0513542	total: 7.41s	remaining: 52.2ms
# 993:	learn: 0.0512888	total: 7.41s	remaining: 44.7ms
# 994:	learn: 0.0511915	total: 7.42s	remaining: 37.3ms
# 995:	learn: 0.0511233	total: 7.42s	remaining: 29.8ms
# 996:	learn: 0.0510600	total: 7.43s	remaining: 22.4ms
# 997:	learn: 0.0510543	total: 7.44s	remaining: 14.9ms
# 998:	learn: 0.0509905	total: 7.45s	remaining: 7.45ms
# 999:	learn: 0.0509666	total: 7.45s	remaining: 0us
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       793
#            1       0.96      0.82      0.89       131
#
#     accuracy                           0.97       924
#    macro avg       0.97      0.91      0.94       924
# weighted avg       0.97      0.97      0.97       924
#
#
# F1_score  0.8888888888888888
#
# Accuracy_score  0.9707792207792207
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# ******************** BernoulliNB() ********************
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.91       793
#            1       0.33      0.17      0.22       131
#
#     accuracy                           0.83       924
#    macro avg       0.60      0.56      0.56       924
# weighted avg       0.80      0.83      0.81       924
#
#
# F1_score  0.2222222222222222
#
# Accuracy_score  0.8333333333333334
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________

# %%
# we will take the model with heihest f1_score for creating churn_score and churn Flag variable.

# %%
xg = XGBClassifier()

# %%
xg.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
y_xg= xg.predict(x_test)

# %%
f1_score(y_test, y_xg)
# Out:
# 0.8925619834710744

# %% [markdown]
# In the line `df4['Churn_score'] = xg.predict_proba(x)[:, 1]`, we're generating probabilities of churn for each customer in the dataset. By specifically selecting the probabilities corresponding to the positive class (label 1), we're focusing on predicting the likelihood of churn. This approach allows us to gain valuable insights into which customers are more likely to churn, aiding in targeted retention efforts and strategic decision-making to reduce customer attrition.

# %%
df4['Churn_score'] = xg.predict_proba(x)[:, 1]

# %%
len(df4.loc[(df4['Churn'] == 1) & (df4['Churn_score']>0.5)])
# Out:
# 633

# %% [markdown]
# This result indicates that there are 633 entries in DataFrame 'df4' where the 'Churn' label is 1 (indicating churn) and the 'Churn_score' exceeds 0.5, suggesting a high probability of churn among these entries.

# %%
len(df4.loc[(df4['Churn'] == 0) & (df4['Churn_score']<0.5)])
# Out:
# 3958

# %% [markdown]
# This outcome reveals that there are 3958 instances in DataFrame 'df4' where the 'Churn' label is 0 (indicating non-churn) and the 'Churn_score' falls below the 0.5 threshold, suggesting a low probability of churn among these entries.

# %%
# lets create a churn flag

# %%
# threshold:
threshold = 0.5

df4['Churn_flag'] = (df4['Churn_score']> threshold).astype(int)

# %%
df4.head()
# Out:
#    Vmail_Message  Day_Mins  Day_Calls  Day_Charge  Eve_Mins  Eve_Calls  \
# 0       1.351459  1.609682   0.511573    1.609970 -0.065280  -0.062273
# 1       1.428400 -0.359631   1.190031   -0.359920 -0.104269   0.145150
# 2      -0.572075  1.196792   0.720329    1.196964 -1.628923   0.508140
# 3      -0.572075  2.262314  -1.523803    2.262496 -0.003122  -0.632686
# 4      -0.572075 -0.262592   0.668140   -0.262545 -1.072825   1.130409
#
#    Eve_Charge  Night_Mins  Night_Calls  Night_Charge  International_Mins  \
# 0   -0.065095    0.905239    -0.461973      0.904496           -0.126926
# 1   -0.103721    1.104535     0.166412      1.105388            1.325692
# 2   -1.629468   -0.781585     0.218777     -0.780259            0.736793
# 3   -0.003123   -0.076858    -0.566703     -0.077136           -1.461764
# 4   -1.071798   -0.282318     1.108988     -0.282594           -0.087666
#
#    International_calls  International_Charge  CustServ_Calls  Combine_Plans  \
# 0            -0.583487             -0.127700       -0.433885       0.998342
# 1            -0.583487              1.326554       -0.433885       0.998342
# 2             0.230398              0.730310       -1.199068      -0.644106
# 3             1.044284             -1.465614        0.331298       2.640789
# 4            -0.583487             -0.084072        1.096480       2.640789
#
#    Engagement_Score  Total_charges  Total_mint  Total_call  Charge_Difference  \
# 0          1.229019       1.607800    1.453045   -0.051199           1.617777
# 1          1.306596      -0.028016    0.386568    0.814979          -0.212514
# 2         -0.632837       0.277697   -0.608037    0.844847           0.174125
# 3         -0.322528       0.729752   -0.313597   -1.484873           0.926423
# 4         -0.555259      -0.744688   -0.925662    1.621421          -0.733028
#
#    Churn  International_Plan_ yes  Vmail_Plan_ yes  Churn_score  Churn_flag
# 0      0                        0                1     0.000176           0
# 1      0                        0                1     0.001922           0
# 2      0                        0                0     0.004715           0
# 3      0                        1                0     0.001356           0
# 4      0                        1                0     0.001927           0

# %%
len(df4.loc[(df4['Churn_flag'] == 1) & (df4['Churn_score']>0.5)])
# Out:
# 636

# %% [markdown]
# In this context, the 636 instances represent customers who have a high probability of leaving the company ('Churn' label is 1) according to the model's prediction ('Churn_score' exceeds 0.5). These customers warrant special attention for retention efforts or targeted interventions to mitigate the risk of churn.
